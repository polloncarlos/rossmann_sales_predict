# %% [markdown]
# # 0 IMPORTS

# %%
import pandas as pd
import numpy as np
import inflection
import math
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import random
import pickle
import requests
import json

from scipy import stats as ss
from matplotlib.gridspec import GridSpec
from datetime import timedelta
from boruta import BorutaPy
from IPython.display import Image

from sklearn.preprocessing import RobustScaler, MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error

import os
os.chdir('..')
warnings.filterwarnings( 'ignore' )

# %% [markdown]
# ## 0.1 Helper Functions

# %%
def cross_validation(x_training, kfold, model_name, model, verbose=False):
    mae_list  = []
    mape_list = []
    rmse_list = []
    
    for k in reversed(range(1, kfold + 1)):
        
        if verbose:
            print('\nKFold Number: {}'.format(k))
        
        # Definindo janela de validação (6 semanas por fold)
        validation_start_date = x_training['date'].max() - datetime.timedelta(days=k*6*7)
        validation_end_date   = x_training['date'].max() - datetime.timedelta(days=(k-1)*6*7)
        
        # Separando treino e validação (sem leakage!)
        training   = x_training[x_training['date'] < validation_start_date]
        validation = x_training[(x_training['date'] >= validation_start_date) & 
                                (x_training['date'] <= validation_end_date)]
        
        # Preparando features e target
        xtraining    = training.drop(['date', 'sales'], axis=1)
        ytraining    = training['sales']
        
        xvalidation  = validation.drop(['date', 'sales'], axis=1)
        yvalidation  = validation['sales']
        
        # Treinando o modelo
        m = model.fit(xtraining, ytraining)
        
        # Fazendo predição
        yhat = m.predict(xvalidation)
        
        # Calculando métricas (com expm1 porque target está em log)
        m_result = ml_error(model_name, np.expm1(yvalidation), np.expm1(yhat))
        
        # Armazenando resultados de cada fold
        mae_list.append(m_result['MAE'])
        mape_list.append(m_result['MAPE'])
        rmse_list.append(m_result['RMSE'])
    
    # Retornando tabela com média ± desvio padrão
    return pd.DataFrame({
        'Model Name': model_name,
        'MAE CV':  np.round(np.mean(mae_list), 2).astype(str) + ' +/- ' + np.round(np.std(mae_list), 2).astype(str),
        'MAPE CV': np.round(np.mean(mape_list), 2).astype(str) + ' +/- ' + np.round(np.std(mape_list), 2).astype(str),
        'RMSE CV': np.round(np.mean(rmse_list), 2).astype(str) + ' +/- ' + np.round(np.std(rmse_list), 2).astype(str)
    }, index=[0])


def mean_percentage_error(y, yhat):
    """MPE - Mede viés (sinal positivo/negativo)"""
    return np.mean((y - yhat) / y)


def mean_absolute_percentage_error(y, yhat):
    """MAPE - Erro percentual absoluto médio (em decimal ou %)"""
    return np.mean(np.abs((y - yhat) / y))


def ml_error(model_name, y_true, y_pred):
    """
    Retorna tabela com métricas de performance do modelo
    """
    mae  = mean_absolute_error(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    
    return pd.DataFrame({
        'Model Name': model_name,
        'MAE':  mae,
        'MAPE': mape,  
        'RMSE': rmse
    }, index=[0])


def cramer_v( x, y ):
    cm = pd.crosstab( x, y ).as_matrix()
    n = cm.sum()
    r, k = cm.shape
    chi2 = ss.chi2_contingency( cm )[0]
    chi2corr = max( 0, chi2 - (k-1)*(r-1)/(n-1) )
    kcorr = k - (k-1)**2/(n-1)
    rcorr = r - (r-1)**2/(n-1)
    
    return np.sqrt( (chi2corr/n) / ( min( kcorr-1, rcorr-1 ) ) )


def vscode_settings():
    plt.style.use('bmh')
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24

    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option('display.expand_frame_repr', False)

    sns.set()

# %%
vscode_settings()

# %% [markdown]
# ## 0.2 Load data

# %%
df_sales_raw = pd.read_csv('data/train.csv', low_memory=False)
df_store_raw = pd.read_csv('data/store.csv', low_memory=False)

# merge
df_raw = pd.merge(df_sales_raw, df_store_raw, how='left', on='Store')

# %% [markdown]
# # 1 DATA DESCRIPTION

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1 Rename Columns

# %%
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
       'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
       'CompetitionDistance', 'CompetitionOpenSinceMonth',
       'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
       'Promo2SinceYear', 'PromoInterval']

snakecase = lambda x: inflection.underscore(x)
cols_new = list(map(snakecase, cols_old))

# rename
df1.columns = cols_new
df1.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'customers', 'open', 'promo',
#        'state_holiday', 'school_holiday', 'store_type', 'assortment',
#        'competition_distance', 'competition_open_since_month',
#        'competition_open_since_year', 'promo2', 'promo2_since_week',
#        'promo2_since_year', 'promo_interval'],
#       dtype='object')

# %% [markdown]
# ## 1.2 Data Dimensions

# %%
print('Number of Rows: {}'.format(df1.shape[0]))
print('Number of Cols: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 1017209
# Number of Cols: 18

# %% [markdown]
# ## 1.3 Data Types

# %%
df1['date'] = pd.to_datetime(df1['date'])
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4 Confirm NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 1.5 Fillout NA

# %%
#competition_distance(if NA is listed, it means the competitor is very far from my store or someone forgot to register. Therefore, including the maximum value signifies this.)
df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000.0 if math.isnan(x) else x)

#competition_open_since_month (include the month of the sale, as a competitor's store can interfere with sales growth)
df1['competition_open_since_month'] = (df1.apply(lambda x: x['date'].month 
                                                 if math.isnan(x['competition_open_since_month']) else x['competition_open_since_month'], axis=1))
#competition_open_since_year (include the year of the sale, as a competitor's store can interfere with sales growth)
df1['competition_open_since_year'] = (df1.apply(lambda x: x['date'].year 
                                                 if math.isnan(x['competition_open_since_year']) else x['competition_open_since_year'], axis=1))              
#promo2_since_week (this means that the store didn't participate in promotion 2; there was no continuity from promotion 1 to promotion 2)
df1['promo2_since_week'] = (df1.apply(lambda x: x['date'].week 
                                                 if math.isnan(x['promo2_since_week']) else x['promo2_since_week'], axis=1))       
#promo2_since_year (this means that the store didn't participate in promotion 2; there was no continuity from promotion 1 to promotion 2)
df1['promo2_since_year'] = (df1.apply(lambda x: x['date'].year 
                                                 if math.isnan(x['promo2_since_year']) else x['promo2_since_year'], axis=1))         
#promo_interval
month_map = {
                1: 'Jan',
                2: 'Feb',
                3: 'Mar',
                4: 'Apr',
                5: 'May',
                6: 'Jun',
                7: 'Jul',
                8: 'Aug',
                9: 'Sep',
                10: 'Oct',
                11: 'Nov',
                12: 'Dec',
            }
df1['promo_interval'].fillna(0, inplace=True)
df1['month_map'] = df1['date'].dt.month.map(month_map)
df1['is_promo'] = (df1[['promo_interval','month_map']].apply(lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval']
                                                      .split(',') else 0, axis=1))

# %%
df1.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# month_map                       0
# is_promo                        0
# dtype: int64

# %%
df1.sample(5).T
# Out:
#                                            877574               796061               234603               550810               917276
# store                                         855                  737                  454                  786                  417
# day_of_week                                     1                    4                    5                    7                    7
# date                          2013-05-06 00:00:00  2013-07-18 00:00:00  2015-01-02 00:00:00  2014-02-23 00:00:00  2013-03-31 00:00:00
# sales                                        5330                 6705                 6763                    0                    0
# customers                                     634                 1001                  802                    0                    0
# open                                            1                    1                    1                    0                    0
# promo                                           0                    1                    0                    0                    0
# state_holiday                                   0                    0                    0                    0                    0
# school_holiday                                  0                    0                    1                    0                    0
# store_type                                      a                    a                    a                    a                    a
# assortment                                      a                    a                    a                    a                    c
# competition_distance                         3440                  100                26450                  290                  840
# competition_open_since_month                    5                    5                    1                   11                    3
# competition_open_since_year                  2013                 2007                 2015                 2006                 2013
# promo2                                          1                    1                    0                    1                    1
# promo2_since_week                              45                   31                    1                    5                   10
# promo2_since_year                            2009                 2013                 2015                 2013                 2014
# promo_interval                    Feb,May,Aug,Nov      Jan,Apr,Jul,Oct                    0      Feb,May,Aug,Nov      Jan,Apr,Jul,Oct
# month_map                                     May                  Jul                  Jan                  Feb                  Mar
# is_promo                                        1                    1                    0                    1                    0

# %% [markdown]
# ## 1.6 Change Types

# %%
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %%
df1[['competition_open_since_month', 'competition_open_since_year', 'promo2_since_week', 'promo2_since_year']] = (df1
                                                                                                                  [['competition_open_since_month', 'competition_open_since_year', 'promo2_since_week', 'promo2_since_year']].astype(int))

# %% [markdown]
# ## 1.7 Descriptive Statistical

# %%
num_attributes = df1.select_dtypes( include=['int64', 'float64'])
cat_attributes = df1.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'])

# %% [markdown]
# ### 1.7.1 Numerical attributes

# %%
# Central Tendency - mean, median
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# Dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(min)).T
d3 = pd.DataFrame(num_attributes.apply(max)).T
d4 = pd.DataFrame(num_attributes.apply( lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attributes.apply( lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply( lambda x: x.kurtosis())).T

# concatenate

m = pd.concat([d2,d3,d4,ct1,ct2,d1,d5,d6]).T.reset_index()
m.columns = ['attributes','min','max','range','mean','median','std','skew','kurtosis']

m
# Out:
#                       attributes     min       max     range         mean  median           std       skew    kurtosis
# 0                          store     1.0    1115.0    1114.0   558.429727   558.0    321.908493  -0.000955   -1.200524
# 1                    day_of_week     1.0       7.0       6.0     3.998341     4.0      1.997390   0.001593   -1.246873
# 2                          sales     0.0   41551.0   41551.0  5773.818972  5744.0   3849.924283   0.641460    1.778375
# 3                      customers     0.0    7388.0    7388.0   633.145946   609.0    464.411506   1.598650    7.091773
# 4                           open     0.0       1.0       1.0     0.830107     1.0      0.375539  -1.758045    1.090723
# 5                          promo     0.0       1.0       1.0     0.381515     0.0      0.485758   0.487838   -1.762018
# 6                 school_holiday     0.0       1.0       1.0     0.178647     0.0      0.383056   1.677842    0.815154
# 7           competition_distance    20.0  200000.0  199980.0  5935.442677  2330.0  12547.646829  10.242344  147.789712
# 8   competition_open_since_month     1.0      12.0      11.0     6.786849     7.0      3.311085  -0.042076   -1.232607
# 9    competition_open_since_year  1900.0    2015.0     115.0  2010.324840  2012.0      5.515591  -7.235657  124.071304
# 10                        promo2     0.0       1.0       1.0     0.500564     1.0      0.500000  -0.002255   -1.999999
# 11             promo2_since_week     1.0      52.0      51.0    23.619033    22.0     14.310057   0.178723   -1.184046
# 12             promo2_since_year  2009.0    2015.0       6.0  2012.793297  2013.0      1.662657  -0.784436   -0.210075
# 13                      is_promo     0.0       1.0       1.0     0.165966     0.0      0.372050   1.795644    1.224338

# %%
sns.kdeplot(df1['competition_distance'], shade=True)

# %% [markdown]
# ### 1.7.1 Categorical attributes

# %%
cat_attributes.apply( lambda x: x.unique().shape[0])
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# month_map         12
# dtype: int64

# %%
aux1 = df1[(df1['state_holiday'] != '0') & (df1['sales'] > 0)]

plt.subplot(1, 3, 1)
sns.boxplot(x='state_holiday', y='sales', data=aux1)

plt.subplot(1, 3, 2)
sns.boxplot(x='store_type', y='sales', data=aux1)

plt.subplot(1, 3, 3)
sns.boxplot(x='assortment', y='sales', data=aux1)

# %% [markdown]
# # 2.0 FEATURE ENGINEERING

# %%
df2 = df1.copy()

# %%
Image('img/mind_map.png')

# %% [markdown]
# ## 2.1 Creation of Hypotheses

# %% [markdown]
# ### 2.1.1 Hypotheeses Store

# %% [markdown]
# **1 -** Lojas com numero maior de funcionarios deveriam vender mais.
#
# **2 -** Lojas com maior capacidade de estoque deveriam vender mais.
#
# **3 -** Lojas com maior porte deveriam vender mais.
#
# **4 -** Lojas com maior variedade deveriam vender mais.
#
# **5 -** Lojas com competidores mais proximos deveriam vender menos.
#
# **6 -** Lojas com competidores a mais tempo deveriam vender mais.

# %% [markdown]
# ### 2.1.2 Hypotheeses Product

# %% [markdown]
# **1 -** Lojas que investem mais em Marketing deveriam vender mais.
#
# **2 -** Lojas com maior exposicao de produtos deveriam vender mais.
#
# **3 -** Lojas com produtos com preco menor deveriam vender mais.
#
# **4 -** Lojas com promocoes mais agressivas deveriam vender mais.
#
# **5 -** Lojas com promocoes ativas por mais tempo deveriam vender mais.
#
# **6 -** Lojas com mais dias de promocao deveriam vender mais.
#
# **7 -** Lojas com mais promocoes consecutivas deveriam vender mais.

# %% [markdown]
# ### 2.1.2 Hypotheeses Seasonality

# %% [markdown]
# **1 -** Lojas abertas durante o feriado de natal deveriam vender mais.
#
# **2 -** Lojas deveriam vender mais ao longo dos anos.
#
# **3 -** Lojas deveriam vender mais no segundo semestre do ano
#
# **4 -** Lojas deveriam vender mais depois do dia 10 de cada mes.
#
# **5 -** Lojas deveriam vender menos aos finais de semana.
#
# **6 -** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.2 Final List - Hypotheses

# %% [markdown]
# **1 -** Lojas com maior variedade deveriam vender mais.
#
# **2 -** Lojas com competidores mais proximos deveriam vender menos.
#
# **3 -** Lojas com competidores a mais tempo deveriam vender mais.
#
# -----------
#
# **4 -** Lojas com promocoes ativas por mais tempo deveriam vender mais.
#
# **5 -** Lojas com mais dias de promocao deveriam vender mais.
#
# **6 -** Lojas com mais promocoes consecutivas deveriam vender mais.
#
# -----------
#
# **7 -** Lojas abertas durante o feriado de natal deveriam vender mais.
#
# **8 -** Lojas deveriam vender mais ao longo dos anos.
#
# **9 -** Lojas deveriam vender mais no segundo semestre do ano
#
# **10 -** Lojas deveriam vender mais depois do dia 10 de cada mes.
#
# **11 -** Lojas deveriam vender menos aos finais de semana.
#
# **12 -** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.3 Feature Engineering

# %%
# year
df2['year'] = df2['date'].dt.year
# month
df2['month'] = df2['date'].dt.month
# day
df2['day'] = df2['date'].dt.day
# week of year
df2['week_of_year'] = df2['date'].dt.weekofyear
# year week
df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

# competition since
df2['competition_since'] = df2.apply(lambda x: datetime.datetime(year=x['competition_open_since_year'], month=x['competition_open_since_month'], day=1), axis=1)
df2['competition_time_month'] = ((df2['date'] - df2['competition_since'])/30).apply(lambda x: x.days).astype(int)
# promo since
df2['promo_since'] = df2['promo2_since_year'].astype(str) + '-' + df2['promo2_since_week'].astype(str)
df2['promo_since'] = df2['promo_since'].apply(lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w') - timedelta(days = 7))
df2['promo_time_week'] = ((df2['date'] - df2['promo_since'])/7).apply(lambda x: x.days).astype(int)

# assortment
df2['assortment'] = df2['assortment'].apply(lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended')
# state holiday
df2['state_holiday'] = (df2['state_holiday'].apply(lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' 
                                                   if x == 'b' else 'christmas' if x == 'c' else 'regular_day'))

# %%
df2.sample(5).T
# Out:
#                                            504224               618586               493631               3912                 221874
# store                                        1030                  547                  472                  568                 1105
# day_of_week                                     7                    2                    2                    2                    3
# date                          2014-04-06 00:00:00  2013-12-24 00:00:00  2014-04-15 00:00:00  2015-07-28 00:00:00  2015-01-14 00:00:00
# sales                                           0                 3275                 7514                 5677                 5050
# customers                                       0                  347                  850                  425                  545
# open                                            0                    1                    1                    1                    1
# promo                                           0                    0                    1                    1                    1
# state_holiday                         regular_day          regular_day          regular_day          regular_day          regular_day
# school_holiday                                  0                    1                    0                    1                    0
# store_type                                      a                    d                    c                    d                    c
# assortment                                  basic             extended             extended             extended             extended
# competition_distance                        36410                 8990                 5030                 4270                  330
# competition_open_since_month                    4                   11                    8                    7                   11
# competition_open_since_year                  2008                 2009                 2011                 2015                 2008
# promo2                                          0                    1                    0                    1                    1
# promo2_since_week                              14                   35                   16                    1                    5
# promo2_since_year                            2014                 2010                 2014                 2013                 2013
# promo_interval                                  0     Mar,Jun,Sept,Dec                    0      Jan,Apr,Jul,Oct      Feb,May,Aug,Nov
# month_map                                     Apr                  Dec                  Apr                  Jul                  Jan
# is_promo                                        0                    1                    0                    1                    0
# year                                         2014                 2013                 2014                 2015                 2015
# month                                           4                   12                    4                    7                    1
# day                                             6                   24                   15                   28                   14
# week_of_year                                   14                   52                   16                   31                    3
# year_week                                 2014-13              2013-51              2014-15              2015-30              2015-02
# competition_since             2008-04-01 00:00:00  2009-11-01 00:00:00  2011-08-01 00:00:00  2015-07-01 00:00:00  2008-11-01 00:00:00
# competition_time_month                         73                   50                   32                    0                   75
# promo_since                   2014-03-31 00:00:00  2010-08-23 00:00:00  2014-04-14 00:00:00  2012-12-31 00:00:00  2013-01-28 00:00:00
# promo_time_week                                 0                  174                    0                  134                  102

# %% [markdown]
# # 3.0 VARIABLE FILTERING

# %%
df3 = df2.copy()

# %%
df3.head()
# Out:
#    store  day_of_week       date  sales  customers  open  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year   promo_interval month_map  is_promo  year  month  day  week_of_year year_week competition_since  competition_time_month promo_since  promo_time_week
# 0      1            5 2015-07-31   5263        555     1      1   regular_day               1          c      basic                1270.0                             9                         2008       0                 31               2015                0       Jul         0  2015      7   31            31   2015-30        2008-09-01                      84  2015-07-27                0
# 1      2            5 2015-07-31   6064        625     1      1   regular_day               1          a      basic                 570.0                            11                         2007       1                 13               2010  Jan,Apr,Jul,Oct       Jul         1  2015      7   31            31   2015-30        2007-11-01                      94  2010-03-22              279
# 2      3            5 2015-07-31   8314        821     1      1   regular_day               1          a      basic               14130.0                            12                         2006       1                 14               2011  Jan,Apr,Jul,Oct       Jul         1  2015      7   31            31   2015-30        2006-12-01                     105  2011-03-28              226
# 3      4            5 2015-07-31  13995       1498     1      1   regular_day               1          c   extended                 620.0                             9                         2009       0                 31               2015                0       Jul         0  2015      7   31            31   2015-30        2009-09-01                      71  2015-07-27                0
# 4      5            5 2015-07-31   4822        559     1      1   regular_day               1          a      basic               29910.0                             4                         2015       0                 31               2015                0       Jul         0  2015      7   31            31   2015-30        2015-04-01                       4  2015-07-27                0

# %% [markdown]
# ## 3.1 Line Filtering

# %%
df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

# %% [markdown]
# ## 3.2 Columns Selection

# %%
cols_drop = ['customers', 'open', 'promo_interval', 'month_map']
df3 = df3.drop(cols_drop, axis=1)

# %%
df3.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'promo', 'state_holiday',
#        'school_holiday', 'store_type', 'assortment', 'competition_distance',
#        'competition_open_since_month', 'competition_open_since_year', 'promo2',
#        'promo2_since_week', 'promo2_since_year', 'is_promo', 'year', 'month',
#        'day', 'week_of_year', 'year_week', 'competition_since',
#        'competition_time_month', 'promo_since', 'promo_time_week'],
#       dtype='object')

# %% [markdown]
# # 4.0 EDA

# %%
df4 = df3.copy()

# %% [markdown]
# **1 -** Lojas com maior sortimento deveriam vender mais.
#
# **2 -** Lojas com competidores mais proximos deveriam vender menos.
#
# **3 -** Lojas com competidores a mais tempo deveriam vender mais.
#
# -----------
#
# **4 -** Lojas com promocoes ativas por mais tempo deveriam vender mais.
#
# **5 -** Lojas com mais dias de promocao deveriam vender mais.
#
# **6 -** Lojas com mais promocoes consecutivas deveriam vender mais.
#
# -----------
#
# **7 -** Lojas abertas durante o feriado de natal deveriam vender mais.
#
# **8 -** Lojas deveriam vender mais ao longo dos anos.
#
# **9 -** Lojas deveriam vender mais no segundo semestre do ano
#
# **10 -** Lojas deveriam vender mais depois do dia 10 de cada mes.
#
# **11 -** Lojas deveriam vender menos aos finais de semana.
#
# **12 -** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 4.1 Univariate Analysis

# %% [markdown]
# ### 4.1.1 Response Variable

# %%
sns.distplot(df4['sales'], kde=False)

# %% [markdown]
# ### 4.1.2 Numerical Variable

# %%
num_attributes.hist( bins=25);

# %% [markdown]
# ### 4.1.3 Categorical Variable

# %%
# state_holiday
plt.subplot(3, 2, 1)
a = df4[df4['state_holiday'] != 'regular_day']
sns.countplot(a['state_holiday'])

plt.subplot(3, 2, 2)
sns.kdeplot(df4[df4['state_holiday'] == 'public_holiday']['sales'], label='public_holiday', shade=True)
sns.kdeplot(df4[df4['state_holiday'] == 'easter_holiday']['sales'], label='easter_holiday', shade=True)
sns.kdeplot(df4[df4['state_holiday'] == 'christmas']['sales'], label='christmas', shade=True)

# store_type
plt.subplot(3, 2, 3)
sns.countplot(df4['store_type'])

plt.subplot(3, 2, 4)
sns.kdeplot(df4[df4['store_type'] == 'a']['sales'], label='a', shade=True)
sns.kdeplot(df4[df4['store_type'] == 'b']['sales'], label='b', shade=True)
sns.kdeplot(df4[df4['store_type'] == 'c']['sales'], label='c', shade=True)
sns.kdeplot(df4[df4['store_type'] == 'd']['sales'], label='d', shade=True)

# assortment
plt.subplot(3, 2, 5)
sns.countplot(df4['assortment'])

plt.subplot(3, 2, 6)
sns.kdeplot(df4[df4['assortment'] == 'basic']['sales'], label='basic', shade=True)
sns.kdeplot(df4[df4['assortment'] == 'extended']['sales'], label='extended', shade=True)
sns.kdeplot(df4[df4['assortment'] == 'extra']['sales'], label='extra', shade=True);

# %% [markdown]
# ## 4.2 Bivariate Analysis

# %% [markdown]
# ### **H1 -** Lojas com maior sortimento deveriam vender mais.
#
# **FALSA** Lojas com MAIOR SORTIMENTO vendem MENOS.

# %%
# --- Graph 1
aux1 = df4[['assortment', 'sales']].groupby('assortment').sum().reset_index()
sns.barplot(x='assortment', y='sales', data=aux1)
plt.title("Total Sales by Assortment Type")

# --- Graph 2
aux2 = df4[['year_week', 'assortment', 'sales']].groupby(['year_week', 'assortment']).sum().reset_index()
aux2.pivot( index='year_week', columns='assortment', values='sales').plot()
plt.title("Weekly Sales by Assortment Type")

# --- Graph 3
aux3 = aux2[aux2['assortment'] == 'extra']
aux3.pivot( index='year_week', columns='assortment', values='sales').plot()
plt.title("Weekly Sales — Assortment Extra");

# %% [markdown]
# ### **H2 -** Lojas com competidores mais proximos deveriam vender menos.
# **FALSA** Lojas com COMPETIDORES MAIS PRÓXIMOS vendem MAIS.

# %%
# -- Graph 1
plt.subplot(1,3,1)
aux1 = df4[['competition_distance', 'sales']].groupby(['competition_distance']).sum().reset_index()
bins = list(np.arange(0, 20000, 1000))
aux1['competition_distance_binned'] = pd.cut(aux1['competition_distance'], bins=bins)
aux2 = aux1[['competition_distance_binned', 'sales']].groupby(['competition_distance_binned']).sum().reset_index()
sns.barplot(x='competition_distance_binned', y='sales', data=aux2)
plt.title("Total Sales by Competition Distance")
plt.xticks(rotation=90)

# -- Graph 2
plt.subplot(1,3,2)
aux1 = df4[['competition_distance', 'sales']].groupby(['competition_distance']).sum().reset_index()
sns.scatterplot(x='competition_distance', y='sales', data=aux1)
plt.title("Total Sales by Competition Distance (Scatter)")

# -- Graph 3
plt.subplot(1,3,3)
sns.heatmap(aux1.corr(method='pearson'), annot=True)
plt.title("Total Sales by Competition Distance (Heatmap)");

# %% [markdown]
# ### **H3 -** Lojas com competidores a mais tempo deveriam vender mais.
# **FALSA** Lojas com COMPETIDORES HA MAIS TEMPO vendem MENOS.

# %%
# -- Graph 1
plt.subplot(1,3,1)
aux1 = df4[['competition_time_month', 'sales']].groupby(['competition_time_month']).sum().reset_index()
aux2 = aux1[(aux1['competition_time_month'] < 60) & (aux1['competition_time_month'] != 0)]
sns.barplot(x='competition_time_month', y='sales', data=aux2)
plt.xticks(rotation = 90)

# -- Graph 2
plt.subplot(1,3,2)
sns.regplot(x='competition_time_month', y='sales', data=aux2)

# -- Graph 3
plt.subplot(1,3,3)
x = sns.heatmap(aux1.corr(method='pearson'), annot=True)
bottom, top = x.get_ylim()
x.set_ylim(bottom+0.5, top-0.5);

# %% [markdown]
# ### **H4 -** Lojas com promocoes ativas por mais tempo deveriam vender mais.
# **FALSA** Lojas com promocoes ativas POR MAIS TEMPO vendem MENOS, depois de um periodo de promocao.

# %%
aux1 = df4[['promo_time_week', 'sales']].groupby(['promo_time_week']).sum().reset_index()

grid = GridSpec(2,3)

# -- Graph 1 - Extended Promo
plt.subplot( grid[0,0])
aux2 = aux1[aux1['promo_time_week'] > 0 ] # extended
plt.title('Extended Promo')
sns.barplot(x='promo_time_week', y='sales', data=aux2)
plt.xticks( rotation=90)

# -- Graph 2 - Tendency Extended Promo
plt.subplot(grid[0,1])
sns.regplot(x='promo_time_week', y='sales', data=aux2)

# -- Graph 3 - Regular Promo
plt.subplot( grid[1,0])
aux3 = aux1[aux1['promo_time_week'] < 0 ] # regular
plt.title('Regular Promo')
sns.barplot(x='promo_time_week', y='sales', data=aux3)
plt.xticks( rotation=90)

# -- Graph 3 - Tendency Regular Promo
plt.subplot( grid[1,1])
sns.regplot(x='promo_time_week', y='sales', data=aux3)

# -- Graph 4 - Correlation
plt.subplot( grid[:,2])
sns.heatmap( aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### <s>**H5 -** Lojas com mais dias de promocao deveriam vender mais.</s>

# %% [markdown]
# ### **H6 -** Lojas com mais promocoes consecutivas deveriam vender mais.
# **FALSA** Lojas com promocoes CONSECUTIVAS vendem MENOS

# %%
df4[['promo', 'promo2', 'sales']].groupby(['promo', 'promo2']).sum().reset_index().sort_values(by=['sales'], ascending=True)
# Out:
#    promo  promo2       sales
# 1      0       1  1289362241
# 3      1       1  1472275754
# 0      0       0  1482612096
# 2      1       0  1628930532

# %%
# -- Graph 1 - Regular & Extended promo
aux1 = df4[(df4['promo'] == 1) & (df4['promo2'] == 1)][['year_week', 'sales']].groupby('year_week').sum().reset_index()
ax = aux1.plot()

# -- Graph 2 - Regular promo
aux2 = df4[(df4['promo'] == 1) & (df4['promo2'] == 0)][['year_week', 'sales']].groupby('year_week').sum().reset_index()
aux2.plot(ax=ax)

ax.legend(labels=['Regular & Extended', 'Regular'])

# %% [markdown]
# ### **H7 -** Lojas abertas durante o feriado de natal deveriam vender mais.
# **FALSA** Lojas abertas durante o feriado de natal vendem MENOS

# %%
aux = df4[df4['state_holiday'] != 'regular_day']

plt.subplot(1,2,1)
aux1 = aux[['state_holiday', 'sales']].groupby('state_holiday').sum().reset_index()
sns.barplot( x = 'state_holiday', y='sales', data=aux1)

plt.subplot(1,2,2)
aux2 = aux[['year', 'state_holiday', 'sales']].groupby(['year', 'state_holiday']).sum().reset_index()
sns.barplot(x='year', y='sales', hue='state_holiday', data=aux2);

# %% [markdown]
# ### **H8 -** Lojas deveriam vender mais ao longo dos anos.
# **FALSA** Lojas vendem MENOS ao longo dos anos

# %%
aux = df4[['year', 'sales']].groupby(['year']).sum().reset_index()

plt.subplot(1,3,1)
sns.barplot(x='year', y='sales', data=aux)

plt.subplot(1,3,2)
sns.regplot(x='year', y='sales', data=aux)

plt.subplot(1,3,3)
sns.heatmap(aux.corr(method='pearson'), annot=True);

# %% [markdown]
# ### **H9 -** Lojas deveriam vender mais no segundo semestre do ano
# **FALSA** Lojas vendem MENOS no segundo semestre do ano

# %%
aux = df4[['month', 'sales']].groupby(['month']).sum().reset_index()

plt.subplot(1,3,1)
sns.barplot(x='month', y='sales', data=aux)

plt.subplot(1,3,2)
sns.regplot(x='month', y='sales', data=aux)

plt.subplot(1,3,3)
sns.heatmap(aux.corr(method='pearson'), annot=True);

# %% [markdown]
# ### **H10 -** Lojas deveriam vender mais depois do dia 10 de cada mes
# **VERDADEIRA** Lojas vendem MAIS depois do dia 10

# %%
aux = df4[['day', 'sales']].groupby(['day']).sum().reset_index()

plt.subplot(2,2,1)
sns.barplot(x='day', y='sales', data=aux)

plt.subplot(2,2,2)
sns.regplot(x='day', y='sales', data=aux)

plt.subplot(2,2,3)
sns.heatmap(aux.corr(method='pearson'), annot=True)


aux['before_after'] = aux['day'].apply(lambda x: 'before_10_days' if x <= 10 else 'after_10_days')
aux1 = aux[['before_after', 'sales']].groupby(['before_after']).sum().reset_index()

plt.subplot(2,2,4)
sns.barplot(x ='before_after', y='sales', data=aux1);

# %% [markdown]
# ### **H11 -** Lojas deveriam vender menos aos finais de semana.
# **VERDADEIRA** Lojas vendem MENOS aos finais de semana

# %%
aux = df4[['day_of_week', 'sales']].groupby(['day_of_week']).sum().reset_index()

plt.subplot(1,3,1)
sns.barplot(x='day_of_week', y='sales', data=aux)

plt.subplot(1,3,2)
sns.regplot(x='day_of_week', y='sales', data=aux)

plt.subplot(1,3,3)
sns.heatmap(aux.corr(method='pearson'), annot=True);

# %% [markdown]
# ### **H12 -** Lojas deveriam vender menos durante os feriados escolares.
# **VERDADEIRA** Lojas vendem MENOS durante os feriados escolares, exceto Julho e Agosto.

# %%
aux1 = df4[['school_holiday', 'sales']].groupby('school_holiday').sum().reset_index()

plt.subplot(2,1,1)
sns.barplot(x='school_holiday', y='sales', data=aux1)

aux2 = df4[['month', 'school_holiday', 'sales']].groupby(['month', 'school_holiday']).sum().reset_index()

plt.subplot(2,1,2)
sns.barplot(x='month', y='sales', hue='school_holiday', data=aux2);

# %% [markdown]
# ### Resume Analysis

# %%
resumo_bivariada = pd.DataFrame({
    'Hipóteses': ['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9', 'H10', 'H11', 'H12'],
    'Conclusão': ['Falsa', 'Falsa', 'Falsa', 'Falsa', '-', 'Falsa', 'Falsa', 'Falsa', 'Falsa', 'Verdadeira', 'Verdadeira', 'Verdadeira'],
    'Relevância': ['Baixa', 'Média', 'Média', 'Baixa', '-', 'Baixa', 'Média', 'Alta', 'Alta', 'Alta', 'Alta', 'Baixa']
})

plt.figure(figsize=(10, 6))
plt.axis('off')

table = plt.table(cellText=resumo_bivariada.values,
                  colLabels=resumo_bivariada.columns,
                  cellLoc='center',
                  loc='center',
                  colWidths=[0.18, 0.28, 0.28])

table.auto_set_font_size(False)
table.set_fontsize(13)
table.scale(1, 2.6)

# Cabeçalho
for i in range(3):
    table[(0, i)].set_facecolor('#2c5282')
    table[(0, i)].set_text_props(weight='bold', color='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.3 Multivariate Analysis

# %% [markdown]
# ### 4.3.1 Numerical Attributes

# %%
correlation = num_attributes.corr(method='pearson')
sns.heatmap(correlation, annot=True);

# %% [markdown]
# ### 4.3.2 Categorical Attributes

# %%
a = df4.select_dtypes( include='object')

# cramer V
a1 = cramer_v( a['state_holiday'], a['state_holiday'] )
a2 = cramer_v( a['state_holiday'], a['store_type'] )
a3 = cramer_v( a['state_holiday'], a['assortment'] )
a4 = cramer_v( a['store_type'], a['state_holiday'] )
a5 = cramer_v( a['store_type'], a['store_type'] )
a6 = cramer_v( a['store_type'], a['assortment'] )
a7 = cramer_v( a['assortment'], a['state_holiday'] )
a8 = cramer_v( a['assortment'], a['store_type'] )
a9 = cramer_v( a['assortment'], a['assortment'] )

# Final
d = pd.DataFrame( {'state_holiday': [a1, a2, a3],
'store_type': [a4, a5, a6],
'assortment': [a7, a8, a9] })
d = d.set_index( d.columns )
sns.heatmap( d, annot=True )

# %% [markdown]
# # 5.0 DATA PREPARATION

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1 Normalization

# %% [markdown]
# ## 5.2 Rescaling

# %%
rs = RobustScaler()
mms = MinMaxScaler()


# competition distance
df5['competition_distance'] = rs.fit_transform(df5[['competition_distance']].values)
pickle.dump(rs, open ('parameter/competition_distance_scaler.pkl', 'wb'))

# competition time month
df5['competition_time_month'] = rs.fit_transform(df5[['competition_time_month']].values)
pickle.dump(rs, open ('parameter/competition_time_month_scaler.pkl', 'wb'))

# promo time week
df5['promo_time_week'] = mms.fit_transform(df5[['promo_time_week']].values)
pickle.dump(rs, open ('parameter/promo_time_week_scaler.pkl', 'wb'))

# year
df5['year'] = mms.fit_transform(df5[['year']].values)
pickle.dump(mms, open ('parameter/year_scaler.pkl', 'wb'))

# %% [markdown]
# ## 5.3 Transform

# %% [markdown]
# ### 5.3.1 Encoding

# %%
# state_holiday - One Hot Encoding
df5 = pd.get_dummies(df5, prefix=['state_holiday'], columns=['state_holiday'])

#store_type - Label Encoding
le = LabelEncoder()
df5['store_type'] = le.fit_transform(df5['store_type'])
pickle.dump(le, open('parameter/store_type_scaler.pkl', 'wb'))


#assortment - Ordinal Encoding
assortment_dict = {'basic': 1,
                   'extra': 2,
                   'extended': 3}
df5['assortment'] = df5['assortment'].map(assortment_dict)

# %% [markdown]
# ### 5.3.2 Response Variable Transformation

# %%
df5['sales'] = np.log1p(df5['sales'])

# %% [markdown]
# ### 5.3.3 Nature Transformation

# %%
# day_of_week
df5['day_of_week_sin'] = df5['day_of_week'].apply(lambda x: np.sin( x * ( 2. * np.pi/7)))
df5['day_of_week_cos'] = df5['day_of_week'].apply(lambda x: np.cos( x * ( 2. * np.pi/7)))

#month
df5['month_sin'] = df5['month'].apply(lambda x: np.sin( x * ( 2. * np.pi/12)))
df5['month_cos'] = df5['month'].apply(lambda x: np.cos( x * ( 2. * np.pi/12)))

#day
df5['day_sin'] = df5['day'].apply(lambda x: np.sin( x * ( 2. * np.pi/30)))
df5['day_cos'] = df5['day'].apply(lambda x: np.cos( x * ( 2. * np.pi/30)))

#week_of_year
df5['week_of_year_sin'] = df5['week_of_year'].apply(lambda x: np.sin( x * ( 2. * np.pi/52)))
df5['week_of_year_cos'] = df5['week_of_year'].apply(lambda x: np.cos( x * ( 2. * np.pi/52)))

# %% [markdown]
# # 6.0 FEATURE SELECTION

# %%
df6 = df5.copy()

# %%
cols_drop = ['week_of_year', 'day', 'month', 'day_of_week', 'promo_since', 'competition_since', 'year_week']
df6 = df6.drop(cols_drop, axis=1)

# %% [markdown]
# ## 6.1 Split traintest

# %%
df6[['store', 'date']].groupby('store').max().reset_index()['date'][0] - datetime.timedelta(days=6*7)
# Out:
# Timestamp('2015-06-19 00:00:00')

# %%
# Train dataset

X_train = df6[df6['date'] < '2015-06-19']
y_train = X_train['sales']

X_test = df6[df6['date'] >= '2015-06-19']
y_test = X_test['sales']

# %% [markdown]
# ## 6.2 Boruta as Feature Selector

# %%
# Dataset for Boruta
X_train_n = X_train.drop(['date', 'sales'], axis=1).values
y_train_n = y_train.values.ravel()

# %%
# RandomForest
#rf = RandomForestRegressor(n_jobs=-1)

# Boruta
#boruta = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42).fit(X_train_n, y_train_n)

# %% [markdown]
# ### 6.2.1 Best Features - Boruta

# %%
#cols_selected = boruta.support_.tolist()

# best features
#X_train_fs = X_train.drop(['date', 'sales'], axis=1)
#cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns.to_list()

# not selected boruta
#cols_not_selected_boruta = list(np.setdiff1d(X_train_fs.columns, cols_selected_boruta))

# %% [markdown]
# ## 6.3 Manual Feature Selection

# %%
cols_selected_boruta = [
    'store',
    'promo',
    'store_type',
    'assortment',
    'competition_distance',
    'competition_open_since_month',
    'competition_open_since_year',
    'promo2',
    'promo2_since_week',
    'promo2_since_year',
    'competition_time_month',
    'promo_time_week',
    'day_of_week_sin',
    'day_of_week_cos',
    'month_sin',
    'month_cos',
    'day_sin',
    'day_cos',
    'week_of_year_sin',
    'week_of_year_cos']

# columns to add

feat_to_add = ['date', 'sales']

# final features
cols_selected_boruta_full = cols_selected_boruta.copy()
cols_selected_boruta_full.extend(feat_to_add)

# %% [markdown]
# # 7.0 MACHINE LEARNING MODEL

# %%
x_train = X_train[cols_selected_boruta]
x_test = X_test[cols_selected_boruta]

# Time Series Data Preparation (variaveis relevantes + vendas e data)
x_training = X_train[cols_selected_boruta_full]

# %% [markdown]
# ## 7.1 Average Model

# %%
aux1 = x_test.copy()
aux1['sales'] = y_test.copy()

# prediction
aux2 = aux1[['store', 'sales']].groupby('store').mean().reset_index().rename(columns={'sales': 'predictions'})
aux1 = pd.merge(aux1, aux2, how='left', on='store')
yhat_baseline = aux1['predictions']

# performance
baseline_result = ml_error('Average Model', np.expm1(y_test), np.expm1(yhat_baseline))
baseline_result
# Out:
#       Model Name          MAE      MAPE         RMSE
# 0  Average Model  1354.800353  0.455051  1835.135542

# %% [markdown]
# ## 7.2 Linear Regression Model

# %%
# model
lr = LinearRegression().fit(x_train, y_train)

# prediction
yhat_lr = lr.predict(x_test)

#performance
lr_result = ml_error('Linear Regression', np.expm1(y_test), np.expm1(yhat_lr))
lr_result
# Out:
#           Model Name          MAE      MAPE         RMSE
# 0  Linear Regression  1867.089774  0.292694  2671.049215

# %% [markdown]
# ### 7.2.1 Linear Regression - Cross Validation

# %%
lr_result_cv = cross_validation(x_training, 5, 'Linear Regression', lr, verbose=True)
lr_result_cv
# Out:
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
#           Model Name              MAE CV       MAPE CV             RMSE CV
# 0  Linear Regression  2081.73 +/- 295.63  0.3 +/- 0.02  2952.52 +/- 468.37

# %% [markdown]
# ## 7.3 Linear Regression Regularized Model - Lasso

# %%
# model
lrr = Lasso( alpha = 0.01 ).fit(x_train, y_train)

# prediction
yhat_lrr = lrr.predict(x_test)

#performance
lrr_result = ml_error('Linear Regression - Lasso', np.expm1(y_test), np.expm1(yhat_lrr))
lrr_result
# Out:
#                   Model Name          MAE      MAPE         RMSE
# 0  Linear Regression - Lasso  1891.704881  0.289106  2744.451737

# %% [markdown]
# ### 7.3.1 - Linear Rergression Lasso - Cross Validation

# %%
lrr_result_cv = cross_validation(x_training, 5, 'Linear Regression Lasso', lrr, verbose=True)
lrr_result_cv
# Out:
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
#                 Model Name             MAE CV        MAPE CV             RMSE CV
# 0  Linear Regression Lasso  2116.38 +/- 341.5  0.29 +/- 0.01  3057.75 +/- 504.26

# %% [markdown]
# ## 7.4 Random Forest Regressor

# %%
# model
rf = RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=42).fit(x_train, y_train)

# prediction
yhat_rf = rf.predict(x_test)

#performance
rf_result = ml_error('Random Forest Regressor', np.expm1(y_test), np.expm1(yhat_rf))
rf_result
# Out:
#                 Model Name         MAE      MAPE        RMSE
# 0  Random Forest Regressor  678.296634  0.099816  1008.24895

# %% [markdown]
# ### 7.4.1 Random Forest - Cross Validation

# %%
rf_result_cv = cross_validation(x_training, 5, 'Random Forest Regressor', rf, verbose=True)
rf_result_cv
# Out:
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
#                 Model Name             MAE CV        MAPE CV             RMSE CV
# 0  Random Forest Regressor  838.18 +/- 218.74  0.12 +/- 0.02  1256.87 +/- 319.67

# %% [markdown]
# ## 7.5 XGBoost

# %%
# model
model_xgb = xgb.XGBRegressor(objective='reg:squarederror',
                             n_estimators=100,
                             eta=0.01,
                             max_depth=10,
                             subsample=0.7,
                             colsample_bytree=0.9).fit(x_train, y_train)

# prediction
yhat_xgb = model_xgb.predict(x_test)

#performance
xgb_result = ml_error('XGBoost Regressor', np.expm1(y_test), np.expm1(yhat_xgb))
xgb_result
# Out:
#           Model Name         MAE      MAPE         RMSE
# 0  XGBoost Regressor  890.527565  0.129193  1306.496922

# %% [markdown]
# ### 7.5.1 XGBoost - Cross Validation

# %%
xgb_result_cv = cross_validation(x_training, 5, 'XGBoost', model_xgb, verbose=True)
xgb_result_cv
# Out:
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
#   Model Name              MAE CV        MAPE CV             RMSE CV
# 0    XGBoost  1048.45 +/- 172.04  0.14 +/- 0.02  1513.27 +/- 234.33

# %% [markdown]
# ## 7.6 Compare Model's Performance

# %% [markdown]
# ### 7.6.1 Single Performance

# %%
modelling_result = pd.concat([baseline_result, lr_result, lrr_result, rf_result, xgb_result])
modelling_result.sort_values('RMSE')
# Out:
#                   Model Name          MAE      MAPE         RMSE
# 0    Random Forest Regressor   678.296634  0.099816  1008.248950
# 0          XGBoost Regressor   890.527565  0.129193  1306.496922
# 0              Average Model  1354.800353  0.455051  1835.135542
# 0          Linear Regression  1867.089774  0.292694  2671.049215
# 0  Linear Regression - Lasso  1891.704881  0.289106  2744.451737

# %% [markdown]
# ### 7.6.2 Real Performance - Cross Validation

# %%
modelling_result_cv = pd.concat([lr_result_cv, lrr_result_cv, rf_result_cv, xgb_result_cv])
modelling_result_cv.sort_values('RMSE CV')
# Out:
#                 Model Name              MAE CV        MAPE CV             RMSE CV
# 0  Random Forest Regressor   838.18 +/- 218.74  0.12 +/- 0.02  1256.87 +/- 319.67
# 0                  XGBoost  1048.45 +/- 172.04  0.14 +/- 0.02  1513.27 +/- 234.33
# 0        Linear Regression  2081.73 +/- 295.63   0.3 +/- 0.02  2952.52 +/- 468.37
# 0  Linear Regression Lasso   2116.38 +/- 341.5  0.29 +/- 0.01  3057.75 +/- 504.26

# %% [markdown]
# # 8.0 FINE TUNING

# %% [markdown]
# ## 8.1 Random Search

# %%
# import random
# import pandas as pd
# import xgboost as xgb

# param = {
#     'n_estimators': [1500, 1700, 2500, 3000, 3500],
#     'eta': [0.01, 0.03],
#     'max_depth': [3, 5, 9],
#     'subsample': [0.1, 0.5, 0.7],
#     'colsample_bytree': [0.3, 0.7, 0.9],
#     'min_child_weight': [3, 8, 15]}

# max_eval = 5

# final_result = pd.DataFrame()

# for i in range(max_eval):

#     hp = {k: random.sample(v, 1)[0] for k, v in param.items()}
#     print(f"\nIteração {i+1}/{max_eval} → {hp}")

#     model_xgb = xgb.XGBRegressor(
#         objective='reg:squarederror',
#         n_estimators=hp['n_estimators'],
#         eta=hp['eta'],
#         max_depth=hp['max_depth'],
#         subsample=hp['subsample'],
#         colsample_bytree=hp['colsample_bytree'],
#         min_child_weight=hp['min_child_weight']
#     )

#     result = cross_validation(
#         x_training,
#         5,
#         'XGBoost Regressor',
#         model_xgb,
#         verbose=True
#     )

#     final_result = pd.concat([final_result, result])
    
# final_result

# %% [markdown]
# ## 8.2 Final Model

# %%
param_tuned = {
    'n_estimators': 3000,
    'eta': 0.03,
    'max_depth': 5,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'min_child_weight': 3
    }


# model
model_xgb_tuned = xgb.XGBRegressor( objective='reg:squarederror',
                                    n_estimators=param_tuned['n_estimators'],
                                    eta=param_tuned['eta'],
                                    max_depth=param_tuned['max_depth'],
                                    subsample=param_tuned['subsample'],
                                    colsample_bytee=param_tuned['colsample_bytree'],
                                    min_child_weight=param_tuned['min_child_weight'],
                                    n_jobs=-1).fit( x_train, y_train )

# prediction
yhat_xgb_tuned = model_xgb_tuned.predict( x_test )

# performance
xgb_result_tuned = ml_error( 'XGBoost Regressor', np.expm1( y_test ), np.expm1(yhat_xgb_tuned))
xgb_result_tuned
# Out:
#           Model Name         MAE      MAPE        RMSE
# 0  XGBoost Regressor  664.974997  0.097529  957.774225

# %%
pe = mean_percentage_error(np.expm1(y_test), np.expm1(yhat_xgb_tuned))
pe
# Out:
# -0.003545334041888066

# %%
 # Save Trained Model
pickle.dump( model_xgb_tuned, open( 'model/model_rossmann.pkl', 'wb' ) )

# %% [markdown]
# # 9.0 TRANSLATING AND INTERPRETING ML ERROR METRICS

# %%
df9 = X_test[cols_selected_boruta_full]

# rescale
df9['sales'] = np.expm1(df9['sales'])
df9['predictions'] = np.expm1(yhat_xgb_tuned)

# %% [markdown]
# ## 9.1 Business Performance

# %%
# sum of predictions
df91 = df9[['store', 'predictions']].groupby( 'store' ).sum().reset_index()

# MAE and MAPE

df9_aux1 = df9[['store', 'sales', 'predictions']].groupby( 'store' ).apply(lambda x: mean_absolute_error( x['sales'], x['predictions'] ) ).reset_index().rename( columns={0:'MAE'})
df9_aux2 = df9[['store', 'sales', 'predictions']].groupby( 'store' ).apply(lambda x: mean_absolute_percentage_error( x['sales'], x['predictions'] ) ).reset_index().rename( columns={0:'MAPE'})

# Merge
df9_aux3 = pd.merge( df9_aux1, df9_aux2, how='inner', on='store' )
df92 = pd.merge( df91, df9_aux3, how='inner', on='store' )

# Scenarios
df92['worst_scenario'] = df92['predictions'] - df92['MAE']
df92['best_scenario'] = df92['predictions'] + df92['MAE']

# order columns
df92 = df92[['store', 'predictions', 'worst_scenario', 'best_scenario', 'MAE','MAPE']]

# %%
df92.sort_values( 'MAPE', ascending=False ).head()
# Out:
#      store    predictions  worst_scenario  best_scenario          MAE      MAPE
# 291    292  104033.085938   100714.981535  107351.190340  3318.104402  0.565828
# 908    909  238233.875000   230573.337254  245894.412746  7660.537746  0.520433
# 875    876  203030.156250   199110.952414  206949.360086  3919.203836  0.305099
# 721    722  353005.781250   351013.625119  354997.937381  1992.156131  0.268338
# 594    595  400883.625000   397415.263170  404351.986830  3468.361830  0.242192

# %%
sns.scatterplot( x='store', y='MAPE', data=df92 );

# %% [markdown]
# ## 9.2 Total Performance

# %%
df93 = df92[['predictions', 'worst_scenario', 'best_scenario']].apply( lambda x: np.sum( x ), axis=0 ).reset_index().rename( columns={'index': 'Scenario', 0:'Values'} )
df93['Values'] = df93['Values'].map( 'R${:,.2f}'.format )
df93
# Out:
#          Scenario            Values
# 0     predictions  R$285,860,497.84
# 1  worst_scenario  R$285,115,015.78
# 2   best_scenario  R$286,605,979.91

# %% [markdown]
# ## 9.3 Machine Learning Performance

# %%
df9['error'] = df9['sales'] - df9['predictions']
df9['error_rate'] = df9['predictions'] / df9['sales']

# %%
plt.subplot( 2, 2, 1 )
sns.lineplot( x='date', y='sales', data=df9, label='SALES' )
sns.lineplot( x='date', y='predictions', data=df9, label='PREDICTIONS' )

plt.subplot( 2, 2, 2 )
sns.lineplot( x='date', y='error_rate', data=df9 )
plt.axhline( 1, linestyle='--')

plt.subplot( 2, 2, 3 )
sns.distplot( df9['error'] )

plt.subplot( 2, 2, 4 )
sns.scatterplot( df9['predictions'], df9['error'] );

# %% [markdown]
# # 10 - DEPLOY MODEL TO PRODUCTION

# %% [markdown]
# ## 10.1 Rossmann Class

# %%
import pickle
import inflection
import pandas as pd
import numpy as np
import math
import datetime


class Rossmann (object):
    def __init__(self):
        self.home_path                      ='/mnt/c/Users/carlo/OneDrive/repos/ds_producao/'
        self.competition_distance_scaler    = pickle.load(open (self.home_path + 'parameter/competition_distance_scaler.pkl', 'rb'))
        self.competition_time_month_scaler  = pickle.load(open (self.home_path + 'parameter/competition_time_month_scaler.pkl', 'rb'))
        self.promo_time_week_scaler         = pickle.load(open (self.home_path + 'parameter/promo_time_week_scaler.pkl', 'rb'))
        self.year_scaler                    = pickle.load(open (self.home_path + 'parameter/year_scaler.pkl', 'rb'))
        self.store_type_scaler              = pickle.load(open (self.home_path + 'parameter/store_type_scaler.pkl', 'rb'))



    def data_cleaning(self, df1):

        cols_old = ['Store', 'DayOfWeek', 'Date', 'Open', 'Promo',
            'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
            'CompetitionDistance', 'CompetitionOpenSinceMonth',
            'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
            'Promo2SinceYear', 'PromoInterval']

        snakecase = lambda x: inflection.underscore(x)
        cols_new = list(map(snakecase, cols_old))

        # rename
        df1.columns = cols_new


        df1['date'] = pd.to_datetime(df1['date'])

        #competition_distance(if NA is listed, it means the competitor is very far from my store or someone forgot to register. Therefore, including the maximum value signifies this.)
        df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000.0 if math.isnan(x) else x)

        #competition_open_since_month (include the month of the sale, as a competitor's store can interfere with sales growth)
        df1['competition_open_since_month'] = (df1.apply(lambda x: x['date'].month 
                                                        if math.isnan(x['competition_open_since_month']) else x['competition_open_since_month'], axis=1))
        #competition_open_since_year (include the year of the sale, as a competitor's store can interfere with sales growth)
        df1['competition_open_since_year'] = (df1.apply(lambda x: x['date'].year 
                                                        if math.isnan(x['competition_open_since_year']) else x['competition_open_since_year'], axis=1))              
        #promo2_since_week (this means that the store didn't participate in promotion 2; there was no continuity from promotion 1 to promotion 2)
        df1['promo2_since_week'] = (df1.apply(lambda x: x['date'].week 
                                                        if math.isnan(x['promo2_since_week']) else x['promo2_since_week'], axis=1))       
        #promo2_since_year (this means that the store didn't participate in promotion 2; there was no continuity from promotion 1 to promotion 2)
        df1['promo2_since_year'] = (df1.apply(lambda x: x['date'].year 
                                                        if math.isnan(x['promo2_since_year']) else x['promo2_since_year'], axis=1))         
        #promo_interval
        month_map = {
                        1: 'Jan',
                        2: 'Feb',
                        3: 'Mar',
                        4: 'Apr',
                        5: 'May',
                        6: 'Jun',
                        7: 'Jul',
                        8: 'Aug',
                        9: 'Sep',
                        10: 'Oct',
                        11: 'Nov',
                        12: 'Dec',
                    }
        df1['promo_interval'].fillna(0, inplace=True)
        df1['month_map'] = df1['date'].dt.month.map(month_map)
        df1['is_promo'] = (df1[['promo_interval','month_map']].apply(lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval']
                                                            .split(',') else 0, axis=1))

        df1[['competition_open_since_month', 'competition_open_since_year', 'promo2_since_week', 'promo2_since_year']] = (df1[['competition_open_since_month', 'competition_open_since_year', 'promo2_since_week', 'promo2_since_year']].astype(int))
        

        return df1                                                                                                               



    def feature_engineering(self, df2):

        # year
        df2['year'] = df2['date'].dt.year
        # month
        df2['month'] = df2['date'].dt.month
        # day
        df2['day'] = df2['date'].dt.day
        # week of year
        df2['week_of_year'] = df2['date'].dt.weekofyear
        # year week
        df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

        # competition since
        df2['competition_since'] = df2.apply(lambda x: datetime.datetime(year=x['competition_open_since_year'], month=x['competition_open_since_month'], day=1), axis=1)
        df2['competition_time_month'] = ((df2['date'] - df2['competition_since'])/30).apply(lambda x: x.days).astype(int)
        # promo since
        df2['promo_since'] = df2['promo2_since_year'].astype(str) + '-' + df2['promo2_since_week'].astype(str)
        df2['promo_since'] = df2['promo_since'].apply(lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w') - timedelta(days = 7))
        df2['promo_time_week'] = ((df2['date'] - df2['promo_since'])/7).apply(lambda x: x.days).astype(int)

        # assortment
        df2['assortment'] = df2['assortment'].apply(lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended')
        # state holiday
        df2['state_holiday'] = (df2['state_holiday'].apply(lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' 
                                                        if x == 'b' else 'christmas' if x == 'c' else 'regular_day'))

        df2 = df2[df2['open'] != 0]
        cols_drop = ['open', 'promo_interval', 'month_map']
        df2 = df2.drop(cols_drop, axis=1)



    def data_preparation (self, df5):

        # competition distance
        df5['competition_distance'] = self.competition_distance_scaler.fit_transform(df5[['competition_distance']].values)

        # competition time month
        df5['competition_time_month'] = self.competition_time_month_scaler.fit_transform(df5[['competition_time_month']].values)
      
        # promo time week
        df5['promo_time_week'] = self.promo_time_week_scaler.fit_transform(df5[['promo_time_week']].values)
        
        # year
        df5['year'] = self.year_scaler.fit_transform(df5[['year']].values)

        # state_holiday - One Hot Encoding
        df5 = pd.get_dummies(df5, prefix=['state_holiday'], columns=['state_holiday'])

        #store_type - Label Encoding
        df5['store_type'] = self.store_type_scaler.fit_transform(df5['store_type'])

        #assortment - Ordinal Encoding
        assortment_dict = {'basic': 1,
                        'extra': 2,
                        'extended': 3}
        df5['assortment'] = df5['assortment'].map(assortment_dict)

        # day_of_week
        df5['day_of_week_sin'] = df5['day_of_week'].apply(lambda x: np.sin( x * ( 2. * np.pi/7)))
        df5['day_of_week_cos'] = df5['day_of_week'].apply(lambda x: np.cos( x * ( 2. * np.pi/7)))

        #month
        df5['month_sin'] = df5['month'].apply(lambda x: np.sin( x * ( 2. * np.pi/12)))
        df5['month_cos'] = df5['month'].apply(lambda x: np.cos( x * ( 2. * np.pi/12)))

        #day
        df5['day_sin'] = df5['day'].apply(lambda x: np.sin( x * ( 2. * np.pi/30)))
        df5['day_cos'] = df5['day'].apply(lambda x: np.cos( x * ( 2. * np.pi/30)))

        #week_of_year
        df5['week_of_year_sin'] = df5['week_of_year'].apply(lambda x: np.sin( x * ( 2. * np.pi/52)))
        df5['week_of_year_cos'] = df5['week_of_year'].apply(lambda x: np.cos( x * ( 2. * np.pi/52)))

        cols_selected = [
            'store',
            'promo',
            'store_type',
            'assortment',
            'competition_distance',
            'competition_open_since_month',
            'competition_open_since_year',
            'promo2',
            'promo2_since_week',
            'promo2_since_year',
            'competition_time_month',
            'promo_time_week',
            'day_of_week_sin',
            'day_of_week_cos',
            'month_sin',
            'month_cos',
            'day_sin',
            'day_cos',
            'week_of_year_sin',
            'week_of_year_cos']

        return df5[cols_selected]


    def get_prediction( self, model, original_data, test_data ):

        # prediction
        pred = model.predict( test_data )
        
        # join pred into the original data
        original_data['prediction'] = np.expm1( pred )
        return original_data.to_json( orient='records', date_format='iso' )

# %% [markdown]
# ## 10.2 API Handler

# %%
import pickle
import pandas                   as pd
from rossmann.Rossmann          import Rossmann
from flask                      import Flask, request, Response

# loading model
model = pickle.load(open('/mnt/c/Users/carlo/OneDrive/repos/ds_producao/model/model_rossmann.pkl', 'rb'))

# initialize API
app = Flask(__name__)

@app.route('/rossmann/predict', methods=['POST'])
def rossmann_predict():
    test_json = request.get_json()
    
    if test_json: #there is data        
        if isinstance (test_json, dict):                # unique example
            test_raw = pd.DataFrame(test_json, index=[0])
        else:                                           # multiple examples
            test_raw = pd.DataFrame(test_json, columns=test_json[0].keys())

        # instantiate rossmann class
        pipeline = Rossmann()

        # data cleaning
        df1 = pipeline.data_cleaning( test_raw )

        # feature engineering
        df2 = pipeline.feature_engineering( df1 )

        # data preparation
        df3 = pipeline.data_preparation( df2 )

        # prediction
        df_response = pipeline.get_prediction( model, test_raw, df3 )

        return df_response

    else:
        return Response ('{}', status=200, mimetype='application/json')


if __name__ == '__main__':
    app.run('0.0.0.0')

# %% [markdown]
# ## 10.3 API Tester

# %%
# loading test dataset
df10 = pd.read_csv('/mnt/c/Users/carlo/OneDrive/repos/ds_producao/data/test.csv')

# %%
# merge test dataset + store
df_test = pd.merge( df10, df_store_raw, how='left', on='Store' )

# choose store for prediction
#df_test = df_test[df_test['Store'].isin( [24, 12, 22] )]

# remove closed days
df_test = df_test[df_test['Open'] != 0]
df_test = df_test[~df_test['Open'].isnull()]
df_test = df_test.drop( 'Id', axis=1 )

# %%
# convert Dataframe to json
data = json.dumps( df_test.to_dict( orient='records' ) )

# %%
# API Call
url = 'http://0.0.0.0:5000/rossmann/predict'
#url = 'https://rossmann-model-test.herokuapp.com/rossmann/predict'
header = {'Content-type': 'application/json' }
data = data
r = requests.post( url, data=data, headers=header )
print( 'Status Code {}'.format( r.status_code ) )
# Out:
# Status Code 200

# %%
d1 = pd.DataFrame( r.json(), columns=r.json()[0].keys() )

# %%
d2 = d1[['store', 'prediction']].groupby( 'store' ).sum().reset_index()

for i in range( len( d2 ) ):
    print( 'Store Number {} will sell R${:,.2f} in the next 6 weeks'.format(d2.loc[i, 'store'], 
                                                                            d2.loc[i, 'prediction'] ) )
# Out:
# Store Number 1 will sell R$201,770.84 in the next 6 weeks
# Store Number 3 will sell R$251,651.19 in the next 6 weeks
# Store Number 7 will sell R$313,047.87 in the next 6 weeks
# Store Number 8 will sell R$246,503.06 in the next 6 weeks
# Store Number 9 will sell R$237,090.67 in the next 6 weeks
# Store Number 10 will sell R$189,183.19 in the next 6 weeks
# Store Number 11 will sell R$286,868.78 in the next 6 weeks
# Store Number 12 will sell R$235,923.16 in the next 6 weeks
# Store Number 13 will sell R$220,784.14 in the next 6 weeks
# Store Number 14 will sell R$214,875.40 in the next 6 weeks
# Store Number 15 will sell R$280,142.83 in the next 6 weeks
# Store Number 16 will sell R$279,836.28 in the next 6 weeks
# Store Number 19 will sell R$255,097.38 in the next 6 weeks
# Store Number 20 will sell R$270,406.74 in the next 6 weeks
# Store Number 21 will sell R$192,564.22 in the next 6 weeks
# Store Number 22 will sell R$196,447.95 in the next 6 weeks
# Store Number 23 will sell R$202,774.07 in the next 6 weeks
# Store Number 24 will sell R$355,111.90 in the next 6 weeks
# Store Number 25 will sell R$394,972.98 in the next 6 weeks
# Store Number 27 will sell R$259,059.74 in the next 6 weeks
# Store Number 29 will sell R$293,796.08 in the next 6 weeks
# Store Number 30 will sell R$188,947.57 in the next 6 weeks
# Store Number 31 will sell R$208,381.49 in the next 6 weeks
# Store Number 32 will sell R$183,621.48 in the next 6 weeks
# Store Number 33 will sell R$262,625.58 in the next 6 weeks
# Store Number 35 will sell R$364,933.03 in the next 6 weeks
# Store Number 36 will sell R$402,014.90 in the next 6 weeks
# Store Number 38 will sell R$190,827.68 in the next 6 weeks
# Store Number 39 will sell R$187,692.19 in the next 6 weeks
# Store Number 40 will sell R$238,042.37 in the next 6 weeks
# Store Number 41 will sell R$192,098.65 in the next 6 weeks
# Store Number 42 will sell R$420,064.35 in the next 6 weeks
# Store Number 43 will sell R$248,394.68 in the next 6 weeks
# Store Number 45 will sell R$189,536.42 in the next 6 weeks
# Store Number 46 will sell R$199,934.87 in the next 6 weeks
# Store Number 47 will sell R$200,138.04 in the next 6 weeks
# Store Number 48 will sell R$206,012.44 in the next 6 weeks
# Store Number 49 will sell R$229,590.99 in the next 6 weeks
# Store Number 50 will sell R$162,979.53 in the next 6 weeks
# Store Number 51 will sell R$304,363.35 in the next 6 weeks
# Store Number 52 will sell R$316,101.37 in the next 6 weeks
# Store Number 53 will sell R$174,418.72 in the next 6 weeks
# Store Number 56 will sell R$246,526.21 in the next 6 weeks
# Store Number 58 will sell R$228,219.17 in the next 6 weeks
# Store Number 61 will sell R$233,252.39 in the next 6 weeks
# Store Number 62 will sell R$250,647.87 in the next 6 weeks
# Store Number 63 will sell R$233,564.82 in the next 6 weeks
# Store Number 64 will sell R$299,224.12 in the next 6 weeks
# Store Number 66 will sell R$229,258.21 in the next 6 weeks
# Store Number 67 will sell R$368,698.42 in the next 6 weeks
# Store Number 68 will sell R$307,444.23 in the next 6 weeks
# Store Number 69 will sell R$256,480.59 in the next 6 weeks
# Store Number 70 will sell R$285,097.26 in the next 6 weeks
# Store Number 71 will sell R$376,029.37 in the next 6 weeks
# Store Number 72 will sell R$185,385.69 in the next 6 weeks
# Store Number 73 will sell R$220,192.34 in the next 6 weeks
# Store Number 74 will sell R$239,055.62 in the next 6 weeks
# Store Number 75 will sell R$344,219.52 in the next 6 weeks
# Store Number 76 will sell R$395,390.03 in the next 6 weeks
# Store Number 77 will sell R$252,194.59 in the next 6 weeks
# Store Number 79 will sell R$212,200.92 in the next 6 weeks
# Store Number 80 will sell R$277,106.07 in the next 6 weeks
# Store Number 81 will sell R$268,252.69 in the next 6 weeks
# Store Number 82 will sell R$408,724.35 in the next 6 weeks
# Store Number 83 will sell R$208,944.53 in the next 6 weeks
# Store Number 84 will sell R$334,336.52 in the next 6 weeks
# Store Number 86 will sell R$240,957.04 in the next 6 weeks
# Store Number 89 will sell R$225,174.88 in the next 6 weeks
# Store Number 90 will sell R$300,542.08 in the next 6 weeks
# Store Number 91 will sell R$206,757.63 in the next 6 weeks
# Store Number 92 will sell R$299,124.08 in the next 6 weeks
# Store Number 93 will sell R$196,743.32 in the next 6 weeks
# Store Number 94 will sell R$279,061.08 in the next 6 weeks
# Store Number 98 will sell R$236,274.98 in the next 6 weeks
# Store Number 99 will sell R$233,025.28 in the next 6 weeks
# Store Number 100 will sell R$201,578.06 in the next 6 weeks
# Store Number 101 will sell R$278,836.55 in the next 6 weeks
# Store Number 102 will sell R$239,300.71 in the next 6 weeks
# Store Number 105 will sell R$109,547.47 in the next 6 weeks
# Store Number 107 will sell R$245,121.39 in the next 6 weeks
# Store Number 108 will sell R$355,258.34 in the next 6 weeks
# Store Number 109 will sell R$227,181.43 in the next 6 weeks
# Store Number 110 will sell R$180,781.70 in the next 6 weeks
# Store Number 111 will sell R$267,842.16 in the next 6 weeks
# Store Number 112 will sell R$271,284.39 in the next 6 weeks
# Store Number 113 will sell R$197,447.58 in the next 6 weeks
# Store Number 115 will sell R$225,861.46 in the next 6 weeks
# Store Number 117 will sell R$188,482.92 in the next 6 weeks
# Store Number 118 will sell R$293,129.65 in the next 6 weeks
# Store Number 119 will sell R$238,036.91 in the next 6 weeks
# Store Number 120 will sell R$283,849.71 in the next 6 weeks
# Store Number 122 will sell R$272,257.52 in the next 6 weeks
# Store Number 124 will sell R$186,011.79 in the next 6 weeks
# Store Number 126 will sell R$225,718.59 in the next 6 weeks
# Store Number 127 will sell R$245,045.25 in the next 6 weeks
# Store Number 128 will sell R$258,424.05 in the next 6 weeks
# Store Number 129 will sell R$277,022.64 in the next 6 weeks
# Store Number 130 will sell R$222,094.96 in the next 6 weeks
# Store Number 131 will sell R$248,385.75 in the next 6 weeks
# Store Number 132 will sell R$216,690.72 in the next 6 weeks
# Store Number 135 will sell R$236,836.12 in the next 6 weeks
# Store Number 136 will sell R$233,687.79 in the next 6 weeks
# Store Number 137 will sell R$251,988.39 in the next 6 weeks
# Store Number 139 will sell R$200,981.15 in the next 6 weeks
# Store Number 140 will sell R$261,441.83 in the next 6 weeks
# Store Number 141 will sell R$279,232.01 in the next 6 weeks
# Store Number 142 will sell R$146,325.58 in the next 6 weeks
# Store Number 143 will sell R$250,995.78 in the next 6 weeks
# Store Number 144 will sell R$208,823.31 in the next 6 weeks
# Store Number 145 will sell R$339,734.97 in the next 6 weeks
# Store Number 146 will sell R$254,543.24 in the next 6 weeks
# Store Number 147 will sell R$324,872.01 in the next 6 weeks
# Store Number 149 will sell R$233,574.07 in the next 6 weeks
# Store Number 150 will sell R$197,914.03 in the next 6 weeks
# Store Number 152 will sell R$280,958.41 in the next 6 weeks
# Store Number 153 will sell R$269,847.75 in the next 6 weeks
# Store Number 154 will sell R$226,042.92 in the next 6 weeks
# Store Number 155 will sell R$259,955.60 in the next 6 weeks
# Store Number 157 will sell R$345,894.52 in the next 6 weeks
# Store Number 158 will sell R$296,387.23 in the next 6 weeks
# Store Number 159 will sell R$285,459.68 in the next 6 weeks
# Store Number 160 will sell R$207,854.00 in the next 6 weeks
# Store Number 161 will sell R$227,564.55 in the next 6 weeks
# Store Number 162 will sell R$295,271.32 in the next 6 weeks
# Store Number 164 will sell R$177,847.85 in the next 6 weeks
# Store Number 165 will sell R$150,128.96 in the next 6 weeks
# Store Number 166 will sell R$214,481.19 in the next 6 weeks
# Store Number 168 will sell R$239,735.56 in the next 6 weeks
# Store Number 169 will sell R$282,055.91 in the next 6 weeks
# Store Number 170 will sell R$192,716.86 in the next 6 weeks
# Store Number 171 will sell R$328,889.17 in the next 6 weeks
# Store Number 172 will sell R$297,612.54 in the next 6 weeks
# Store Number 174 will sell R$180,306.83 in the next 6 weeks
# Store Number 175 will sell R$253,791.12 in the next 6 weeks
# Store Number 176 will sell R$235,908.65 in the next 6 weeks
# Store Number 179 will sell R$419,943.24 in the next 6 weeks
# Store Number 180 will sell R$250,821.89 in the next 6 weeks
# Store Number 181 will sell R$231,718.68 in the next 6 weeks
# Store Number 182 will sell R$320,255.28 in the next 6 weeks
# Store Number 183 will sell R$249,551.76 in the next 6 weeks
# Store Number 184 will sell R$258,784.74 in the next 6 weeks
# Store Number 186 will sell R$190,191.00 in the next 6 weeks
# Store Number 187 will sell R$267,503.73 in the next 6 weeks
# Store Number 188 will sell R$204,459.42 in the next 6 weeks
# Store Number 189 will sell R$308,205.44 in the next 6 weeks
# Store Number 190 will sell R$254,418.55 in the next 6 weeks
# Store Number 191 will sell R$204,604.34 in the next 6 weeks
# Store Number 192 will sell R$212,474.82 in the next 6 weeks
# Store Number 193 will sell R$223,040.41 in the next 6 weeks
# Store Number 194 will sell R$173,103.01 in the next 6 weeks
# Store Number 195 will sell R$248,684.77 in the next 6 weeks
# Store Number 197 will sell R$239,339.64 in the next 6 weeks
# Store Number 199 will sell R$297,189.69 in the next 6 weeks
# Store Number 200 will sell R$240,948.27 in the next 6 weeks
# Store Number 201 will sell R$231,215.18 in the next 6 weeks
# Store Number 202 will sell R$201,841.20 in the next 6 weeks
# Store Number 204 will sell R$183,957.20 in the next 6 weeks
# Store Number 206 will sell R$311,806.36 in the next 6 weeks
# Store Number 207 will sell R$316,895.55 in the next 6 weeks
# Store Number 209 will sell R$198,174.23 in the next 6 weeks
# Store Number 210 will sell R$140,441.94 in the next 6 weeks
# Store Number 212 will sell R$198,543.50 in the next 6 weeks
# Store Number 213 will sell R$219,426.58 in the next 6 weeks
# Store Number 214 will sell R$312,196.94 in the next 6 weeks
# Store Number 215 will sell R$320,210.77 in the next 6 weeks
# Store Number 216 will sell R$335,307.90 in the next 6 weeks
# Store Number 217 will sell R$232,342.50 in the next 6 weeks
# Store Number 218 will sell R$366,558.09 in the next 6 weeks
# Store Number 219 will sell R$149,115.05 in the next 6 weeks
# Store Number 220 will sell R$209,459.96 in the next 6 weeks
# Store Number 221 will sell R$185,359.79 in the next 6 weeks
# Store Number 224 will sell R$225,793.27 in the next 6 weeks
# Store Number 226 will sell R$344,278.64 in the next 6 weeks
# Store Number 227 will sell R$273,373.76 in the next 6 weeks
# Store Number 228 will sell R$334,872.32 in the next 6 weeks
# Store Number 229 will sell R$339,311.29 in the next 6 weeks
# Store Number 230 will sell R$254,165.63 in the next 6 weeks
# Store Number 231 will sell R$191,589.85 in the next 6 weeks
# Store Number 233 will sell R$326,335.56 in the next 6 weeks
# Store Number 234 will sell R$368,430.22 in the next 6 weeks
# Store Number 235 will sell R$216,736.72 in the next 6 weeks
# Store Number 238 will sell R$368,675.17 in the next 6 weeks
# Store Number 239 will sell R$223,298.92 in the next 6 weeks
# Store Number 241 will sell R$212,369.47 in the next 6 weeks
# Store Number 242 will sell R$179,862.01 in the next 6 weeks
# Store Number 243 will sell R$329,920.49 in the next 6 weeks
# Store Number 244 will sell R$205,638.84 in the next 6 weeks
# Store Number 245 will sell R$259,984.52 in the next 6 weeks
# Store Number 246 will sell R$240,072.59 in the next 6 weeks
# Store Number 247 will sell R$219,531.87 in the next 6 weeks
# Store Number 248 will sell R$445,613.46 in the next 6 weeks
# Store Number 249 will sell R$169,470.91 in the next 6 weeks
# Store Number 250 will sell R$262,464.12 in the next 6 weeks
# Store Number 251 will sell R$422,933.28 in the next 6 weeks
# Store Number 252 will sell R$376,186.01 in the next 6 weeks
# Store Number 253 will sell R$274,737.82 in the next 6 weeks
# Store Number 254 will sell R$189,351.83 in the next 6 weeks
# Store Number 255 will sell R$262,412.06 in the next 6 weeks
# Store Number 256 will sell R$238,633.98 in the next 6 weeks
# Store Number 258 will sell R$211,466.76 in the next 6 weeks
# Store Number 259 will sell R$372,366.62 in the next 6 weeks
# Store Number 262 will sell R$544,841.99 in the next 6 weeks
# Store Number 263 will sell R$144,201.61 in the next 6 weeks
# Store Number 265 will sell R$204,224.28 in the next 6 weeks
# Store Number 267 will sell R$279,641.74 in the next 6 weeks
# Store Number 268 will sell R$163,355.05 in the next 6 weeks
# Store Number 269 will sell R$261,995.47 in the next 6 weeks
# Store Number 272 will sell R$226,373.33 in the next 6 weeks
# Store Number 273 will sell R$287,237.72 in the next 6 weeks
# Store Number 274 will sell R$190,571.86 in the next 6 weeks
# Store Number 275 will sell R$241,283.27 in the next 6 weeks
# Store Number 277 will sell R$248,188.40 in the next 6 weeks
# Store Number 278 will sell R$228,976.83 in the next 6 weeks
# Store Number 279 will sell R$323,077.07 in the next 6 weeks
# Store Number 280 will sell R$220,044.23 in the next 6 weeks
# Store Number 281 will sell R$215,934.18 in the next 6 weeks
# Store Number 283 will sell R$271,248.31 in the next 6 weeks
# Store Number 284 will sell R$183,136.42 in the next 6 weeks
# Store Number 285 will sell R$257,874.69 in the next 6 weeks
# Store Number 287 will sell R$295,409.35 in the next 6 weeks
# Store Number 288 will sell R$201,496.19 in the next 6 weeks
# Store Number 289 will sell R$240,518.49 in the next 6 weeks
# Store Number 290 will sell R$248,141.39 in the next 6 weeks
# Store Number 294 will sell R$231,826.40 in the next 6 weeks
# Store Number 295 will sell R$185,566.31 in the next 6 weeks
# Store Number 296 will sell R$241,212.82 in the next 6 weeks
# Store Number 297 will sell R$259,195.64 in the next 6 weeks
# Store Number 298 will sell R$374,453.85 in the next 6 weeks
# Store Number 299 will sell R$295,835.29 in the next 6 weeks
# Store Number 300 will sell R$244,892.87 in the next 6 weeks
# Store Number 301 will sell R$230,866.40 in the next 6 weeks
# Store Number 302 will sell R$159,586.92 in the next 6 weeks
# Store Number 303 will sell R$259,417.11 in the next 6 weeks
# Store Number 304 will sell R$290,205.96 in the next 6 weeks
# Store Number 305 will sell R$163,712.77 in the next 6 weeks
# Store Number 306 will sell R$158,520.80 in the next 6 weeks
# Store Number 308 will sell R$275,868.54 in the next 6 weeks
# Store Number 309 will sell R$303,556.38 in the next 6 weeks
# Store Number 310 will sell R$378,841.08 in the next 6 weeks
# Store Number 311 will sell R$262,221.35 in the next 6 weeks
# Store Number 312 will sell R$264,536.76 in the next 6 weeks
# Store Number 314 will sell R$164,852.40 in the next 6 weeks
# Store Number 315 will sell R$199,070.22 in the next 6 weeks
# Store Number 316 will sell R$326,528.44 in the next 6 weeks
# Store Number 317 will sell R$236,484.94 in the next 6 weeks
# Store Number 319 will sell R$321,477.35 in the next 6 weeks
# Store Number 320 will sell R$277,375.52 in the next 6 weeks
# Store Number 323 will sell R$263,568.82 in the next 6 weeks
# Store Number 325 will sell R$396,589.81 in the next 6 weeks
# Store Number 326 will sell R$191,466.91 in the next 6 weeks
# Store Number 328 will sell R$193,002.88 in the next 6 weeks
# Store Number 329 will sell R$227,001.45 in the next 6 weeks
# Store Number 330 will sell R$227,282.93 in the next 6 weeks
# Store Number 331 will sell R$241,182.14 in the next 6 weeks
# Store Number 333 will sell R$335,632.34 in the next 6 weeks
# Store Number 334 will sell R$199,056.62 in the next 6 weeks
# Store Number 335 will sell R$509,757.13 in the next 6 weeks
# Store Number 336 will sell R$338,689.36 in the next 6 weeks
# Store Number 337 will sell R$172,664.89 in the next 6 weeks
# Store Number 338 will sell R$316,093.16 in the next 6 weeks
# Store Number 339 will sell R$229,272.60 in the next 6 weeks
# Store Number 340 will sell R$347,012.94 in the next 6 weeks
# Store Number 341 will sell R$196,927.92 in the next 6 weeks
# Store Number 342 will sell R$354,446.26 in the next 6 weeks
# Store Number 343 will sell R$252,894.84 in the next 6 weeks
# Store Number 344 will sell R$311,454.66 in the next 6 weeks
# Store Number 345 will sell R$239,806.19 in the next 6 weeks
# Store Number 346 will sell R$310,335.50 in the next 6 weeks
# Store Number 347 will sell R$209,057.25 in the next 6 weeks
# Store Number 348 will sell R$202,669.18 in the next 6 weeks
# Store Number 350 will sell R$278,188.81 in the next 6 weeks
# Store Number 351 will sell R$225,350.60 in the next 6 weeks
# Store Number 352 will sell R$260,061.80 in the next 6 weeks
# Store Number 353 will sell R$259,207.98 in the next 6 weeks
# Store Number 354 will sell R$344,344.83 in the next 6 weeks
# Store Number 355 will sell R$296,920.62 in the next 6 weeks
# Store Number 356 will sell R$219,690.47 in the next 6 weeks
# Store Number 358 will sell R$399,576.34 in the next 6 weeks
# Store Number 359 will sell R$251,806.37 in the next 6 weeks
# Store Number 362 will sell R$326,234.63 in the next 6 weeks
# Store Number 364 will sell R$162,425.36 in the next 6 weeks
# Store Number 365 will sell R$221,625.45 in the next 6 weeks
# Store Number 367 will sell R$208,220.33 in the next 6 weeks
# Store Number 368 will sell R$348,622.46 in the next 6 weeks
# Store Number 369 will sell R$241,732.71 in the next 6 weeks
# Store Number 370 will sell R$305,396.19 in the next 6 weeks
# Store Number 371 will sell R$256,277.29 in the next 6 weeks
# Store Number 372 will sell R$313,309.87 in the next 6 weeks
# Store Number 373 will sell R$230,305.13 in the next 6 weeks
# Store Number 377 will sell R$264,882.34 in the next 6 weeks
# Store Number 378 will sell R$247,584.00 in the next 6 weeks
# Store Number 379 will sell R$198,844.68 in the next 6 weeks
# Store Number 380 will sell R$439,445.34 in the next 6 weeks
# Store Number 383 will sell R$492,706.42 in the next 6 weeks
# Store Number 385 will sell R$285,806.42 in the next 6 weeks
# Store Number 386 will sell R$306,771.38 in the next 6 weeks
# Store Number 387 will sell R$403,687.10 in the next 6 weeks
# Store Number 388 will sell R$450,891.23 in the next 6 weeks
# Store Number 389 will sell R$418,745.45 in the next 6 weeks
# Store Number 391 will sell R$296,635.81 in the next 6 weeks
# Store Number 392 will sell R$293,360.40 in the next 6 weeks
# Store Number 393 will sell R$222,785.76 in the next 6 weeks
# Store Number 394 will sell R$279,802.22 in the next 6 weeks
# Store Number 395 will sell R$207,798.29 in the next 6 weeks
# Store Number 397 will sell R$313,398.23 in the next 6 weeks
# Store Number 398 will sell R$271,161.07 in the next 6 weeks
# Store Number 399 will sell R$226,879.12 in the next 6 weeks
# Store Number 403 will sell R$315,102.56 in the next 6 weeks
# Store Number 404 will sell R$204,293.65 in the next 6 weeks
# Store Number 405 will sell R$175,223.62 in the next 6 weeks
# Store Number 406 will sell R$199,680.96 in the next 6 weeks
# Store Number 407 will sell R$155,619.64 in the next 6 weeks
# Store Number 408 will sell R$249,530.53 in the next 6 weeks
# Store Number 409 will sell R$165,476.02 in the next 6 weeks
# Store Number 410 will sell R$193,554.38 in the next 6 weeks
# Store Number 411 will sell R$384,495.10 in the next 6 weeks
# Store Number 412 will sell R$362,079.32 in the next 6 weeks
# Store Number 413 will sell R$294,946.79 in the next 6 weeks
# Store Number 414 will sell R$259,906.13 in the next 6 weeks
# Store Number 415 will sell R$239,917.08 in the next 6 weeks
# Store Number 416 will sell R$400,023.60 in the next 6 weeks
# Store Number 417 will sell R$257,550.52 in the next 6 weeks
# Store Number 418 will sell R$259,880.91 in the next 6 weeks
# Store Number 420 will sell R$219,590.72 in the next 6 weeks
# Store Number 421 will sell R$259,307.20 in the next 6 weeks
# Store Number 422 will sell R$298,264.72 in the next 6 weeks
# Store Number 424 will sell R$326,316.36 in the next 6 weeks
# Store Number 425 will sell R$289,393.36 in the next 6 weeks
# Store Number 426 will sell R$281,977.19 in the next 6 weeks
# Store Number 427 will sell R$229,001.96 in the next 6 weeks
# Store Number 428 will sell R$227,162.93 in the next 6 weeks
# Store Number 429 will sell R$208,598.51 in the next 6 weeks
# Store Number 430 will sell R$164,630.99 in the next 6 weeks
# Store Number 431 will sell R$386,301.09 in the next 6 weeks
# Store Number 432 will sell R$364,267.75 in the next 6 weeks
# Store Number 433 will sell R$199,661.01 in the next 6 weeks
# Store Number 434 will sell R$179,307.29 in the next 6 weeks
# Store Number 435 will sell R$243,589.60 in the next 6 weeks
# Store Number 440 will sell R$211,955.55 in the next 6 weeks
# Store Number 441 will sell R$275,086.31 in the next 6 weeks
# Store Number 442 will sell R$277,602.89 in the next 6 weeks
# Store Number 445 will sell R$372,360.05 in the next 6 weeks
# Store Number 446 will sell R$281,895.45 in the next 6 weeks
# Store Number 447 will sell R$266,408.54 in the next 6 weeks
# Store Number 448 will sell R$315,761.63 in the next 6 weeks
# Store Number 449 will sell R$595,022.83 in the next 6 weeks
# Store Number 450 will sell R$302,762.72 in the next 6 weeks
# Store Number 451 will sell R$171,538.78 in the next 6 weeks
# Store Number 452 will sell R$202,181.13 in the next 6 weeks
# Store Number 453 will sell R$332,528.86 in the next 6 weeks
# Store Number 455 will sell R$269,627.86 in the next 6 weeks
# Store Number 456 will sell R$305,379.77 in the next 6 weeks
# Store Number 457 will sell R$124,900.20 in the next 6 weeks
# Store Number 458 will sell R$296,561.51 in the next 6 weeks
# Store Number 459 will sell R$248,174.14 in the next 6 weeks
# Store Number 461 will sell R$191,447.88 in the next 6 weeks
# Store Number 463 will sell R$308,165.68 in the next 6 weeks
# Store Number 465 will sell R$178,056.99 in the next 6 weeks
# Store Number 466 will sell R$309,594.16 in the next 6 weeks
# Store Number 467 will sell R$451,394.17 in the next 6 weeks
# Store Number 468 will sell R$240,679.25 in the next 6 weeks
# Store Number 470 will sell R$375,783.29 in the next 6 weeks
# Store Number 471 will sell R$279,025.21 in the next 6 weeks
# Store Number 472 will sell R$200,777.64 in the next 6 weeks
# Store Number 473 will sell R$226,696.55 in the next 6 weeks
# Store Number 475 will sell R$183,397.41 in the next 6 weeks
# Store Number 477 will sell R$195,662.61 in the next 6 weeks
# Store Number 481 will sell R$190,671.78 in the next 6 weeks
# Store Number 484 will sell R$200,093.47 in the next 6 weeks
# Store Number 485 will sell R$210,465.46 in the next 6 weeks
# Store Number 486 will sell R$214,798.09 in the next 6 weeks
# Store Number 487 will sell R$245,263.19 in the next 6 weeks
# Store Number 488 will sell R$232,709.77 in the next 6 weeks
# Store Number 490 will sell R$251,517.69 in the next 6 weeks
# Store Number 491 will sell R$279,490.78 in the next 6 weeks
# Store Number 492 will sell R$269,115.33 in the next 6 weeks
# Store Number 493 will sell R$254,837.04 in the next 6 weeks
# Store Number 495 will sell R$214,237.79 in the next 6 weeks
# Store Number 497 will sell R$340,659.31 in the next 6 weeks
# Store Number 498 will sell R$309,168.22 in the next 6 weeks
# Store Number 499 will sell R$280,706.65 in the next 6 weeks
# Store Number 500 will sell R$192,902.06 in the next 6 weeks
# Store Number 501 will sell R$286,344.30 in the next 6 weeks
# Store Number 502 will sell R$357,662.15 in the next 6 weeks
# Store Number 504 will sell R$318,294.42 in the next 6 weeks
# Store Number 505 will sell R$274,837.08 in the next 6 weeks
# Store Number 506 will sell R$336,550.49 in the next 6 weeks
# Store Number 507 will sell R$333,060.54 in the next 6 weeks
# Store Number 508 will sell R$346,755.89 in the next 6 weeks
# Store Number 509 will sell R$232,556.59 in the next 6 weeks
# Store Number 510 will sell R$340,286.68 in the next 6 weeks
# Store Number 511 will sell R$283,262.72 in the next 6 weeks
# Store Number 512 will sell R$315,354.10 in the next 6 weeks
# Store Number 514 will sell R$233,383.70 in the next 6 weeks
# Store Number 515 will sell R$400,198.28 in the next 6 weeks
# Store Number 516 will sell R$368,382.23 in the next 6 weeks
# Store Number 517 will sell R$316,153.46 in the next 6 weeks
# Store Number 518 will sell R$242,077.50 in the next 6 weeks
# Store Number 519 will sell R$191,194.74 in the next 6 weeks
# Store Number 520 will sell R$177,350.65 in the next 6 weeks
# Store Number 521 will sell R$189,056.13 in the next 6 weeks
# Store Number 522 will sell R$367,458.02 in the next 6 weeks
# Store Number 524 will sell R$303,349.91 in the next 6 weeks
# Store Number 527 will sell R$370,967.72 in the next 6 weeks
# Store Number 528 will sell R$374,223.92 in the next 6 weeks
# Store Number 529 will sell R$167,413.31 in the next 6 weeks
# Store Number 530 will sell R$188,113.37 in the next 6 weeks
# Store Number 531 will sell R$255,148.62 in the next 6 weeks
# Store Number 532 will sell R$331,974.44 in the next 6 weeks
# Store Number 533 will sell R$465,867.52 in the next 6 weeks
# Store Number 534 will sell R$269,122.89 in the next 6 weeks
# Store Number 535 will sell R$265,176.13 in the next 6 weeks
# Store Number 536 will sell R$319,369.94 in the next 6 weeks
# Store Number 537 will sell R$206,596.05 in the next 6 weeks
# Store Number 538 will sell R$175,203.03 in the next 6 weeks
# Store Number 539 will sell R$336,427.67 in the next 6 weeks
# Store Number 540 will sell R$219,129.71 in the next 6 weeks
# Store Number 541 will sell R$432,709.91 in the next 6 weeks
# Store Number 542 will sell R$209,584.05 in the next 6 weeks
# Store Number 543 will sell R$149,686.28 in the next 6 weeks
# Store Number 545 will sell R$281,576.85 in the next 6 weeks
# Store Number 547 will sell R$241,146.64 in the next 6 weeks
# Store Number 548 will sell R$205,328.55 in the next 6 weeks
# Store Number 549 will sell R$276,869.76 in the next 6 weeks
# Store Number 550 will sell R$289,396.38 in the next 6 weeks
# Store Number 551 will sell R$224,159.18 in the next 6 weeks
# Store Number 552 will sell R$295,411.78 in the next 6 weeks
# Store Number 553 will sell R$236,347.49 in the next 6 weeks
# Store Number 554 will sell R$210,264.34 in the next 6 weeks
# Store Number 555 will sell R$168,912.96 in the next 6 weeks
# Store Number 557 will sell R$252,320.61 in the next 6 weeks
# Store Number 558 will sell R$145,788.74 in the next 6 weeks
# Store Number 561 will sell R$236,351.15 in the next 6 weeks
# Store Number 562 will sell R$712,544.88 in the next 6 weeks
# Store Number 563 will sell R$232,666.67 in the next 6 weeks
# Store Number 564 will sell R$225,385.56 in the next 6 weeks
# Store Number 565 will sell R$216,641.90 in the next 6 weeks
# Store Number 566 will sell R$225,508.46 in the next 6 weeks
# Store Number 567 will sell R$224,835.62 in the next 6 weeks
# Store Number 568 will sell R$210,303.66 in the next 6 weeks
# Store Number 570 will sell R$161,637.57 in the next 6 weeks
# Store Number 571 will sell R$235,070.45 in the next 6 weeks
# Store Number 572 will sell R$272,841.91 in the next 6 weeks
# Store Number 573 will sell R$165,544.00 in the next 6 weeks
# Store Number 574 will sell R$395,054.68 in the next 6 weeks
# Store Number 575 will sell R$202,886.62 in the next 6 weeks
# Store Number 577 will sell R$245,454.03 in the next 6 weeks
# Store Number 578 will sell R$218,739.10 in the next 6 weeks
# Store Number 579 will sell R$331,124.58 in the next 6 weeks
# Store Number 580 will sell R$305,900.37 in the next 6 weeks
# Store Number 581 will sell R$185,074.21 in the next 6 weeks
# Store Number 582 will sell R$335,454.82 in the next 6 weeks
# Store Number 584 will sell R$326,703.76 in the next 6 weeks
# Store Number 585 will sell R$261,179.55 in the next 6 weeks
# Store Number 586 will sell R$286,860.97 in the next 6 weeks
# Store Number 587 will sell R$406,697.51 in the next 6 weeks
# Store Number 588 will sell R$205,786.17 in the next 6 weeks
# Store Number 589 will sell R$253,005.41 in the next 6 weeks
# Store Number 590 will sell R$174,693.31 in the next 6 weeks
# Store Number 591 will sell R$224,095.41 in the next 6 weeks
# Store Number 592 will sell R$164,015.79 in the next 6 weeks
# Store Number 593 will sell R$221,470.74 in the next 6 weeks
# Store Number 597 will sell R$157,533.14 in the next 6 weeks
# Store Number 598 will sell R$194,352.28 in the next 6 weeks
# Store Number 600 will sell R$284,718.57 in the next 6 weeks
# Store Number 601 will sell R$216,811.88 in the next 6 weeks
# Store Number 602 will sell R$225,043.59 in the next 6 weeks
# Store Number 603 will sell R$342,173.40 in the next 6 weeks
# Store Number 604 will sell R$177,053.53 in the next 6 weeks
# Store Number 605 will sell R$281,021.37 in the next 6 weeks
# Store Number 610 will sell R$192,746.40 in the next 6 weeks
# Store Number 611 will sell R$203,235.42 in the next 6 weeks
# Store Number 612 will sell R$224,616.04 in the next 6 weeks
# Store Number 615 will sell R$291,835.93 in the next 6 weeks
# Store Number 616 will sell R$299,190.46 in the next 6 weeks
# Store Number 618 will sell R$298,594.94 in the next 6 weeks
# Store Number 619 will sell R$196,442.30 in the next 6 weeks
# Store Number 620 will sell R$289,015.01 in the next 6 weeks
# Store Number 621 will sell R$211,329.36 in the next 6 weeks
# Store Number 622 will sell R$101,854.79 in the next 6 weeks
# Store Number 623 will sell R$264,202.48 in the next 6 weeks
# Store Number 624 will sell R$273,510.50 in the next 6 weeks
# Store Number 625 will sell R$226,799.48 in the next 6 weeks
# Store Number 627 will sell R$228,097.60 in the next 6 weeks
# Store Number 628 will sell R$294,443.76 in the next 6 weeks
# Store Number 629 will sell R$278,957.82 in the next 6 weeks
# Store Number 631 will sell R$271,782.54 in the next 6 weeks
# Store Number 632 will sell R$222,812.15 in the next 6 weeks
# Store Number 633 will sell R$222,212.00 in the next 6 weeks
# Store Number 636 will sell R$235,356.83 in the next 6 weeks
# Store Number 637 will sell R$349,118.12 in the next 6 weeks
# Store Number 638 will sell R$213,130.59 in the next 6 weeks
# Store Number 639 will sell R$255,413.26 in the next 6 weeks
# Store Number 640 will sell R$409,944.28 in the next 6 weeks
# Store Number 641 will sell R$227,301.16 in the next 6 weeks
# Store Number 642 will sell R$202,220.50 in the next 6 weeks
# Store Number 643 will sell R$255,347.31 in the next 6 weeks
# Store Number 644 will sell R$369,498.12 in the next 6 weeks
# Store Number 645 will sell R$427,317.13 in the next 6 weeks
# Store Number 646 will sell R$186,235.45 in the next 6 weeks
# Store Number 647 will sell R$221,945.31 in the next 6 weeks
# Store Number 650 will sell R$203,483.70 in the next 6 weeks
# Store Number 651 will sell R$334,122.30 in the next 6 weeks
# Store Number 653 will sell R$270,048.76 in the next 6 weeks
# Store Number 655 will sell R$257,012.90 in the next 6 weeks
# Store Number 656 will sell R$217,504.96 in the next 6 weeks
# Store Number 657 will sell R$191,343.70 in the next 6 weeks
# Store Number 658 will sell R$322,221.99 in the next 6 weeks
# Store Number 659 will sell R$236,829.48 in the next 6 weeks
# Store Number 660 will sell R$182,114.42 in the next 6 weeks
# Store Number 661 will sell R$246,317.05 in the next 6 weeks
# Store Number 662 will sell R$316,719.60 in the next 6 weeks
# Store Number 663 will sell R$145,449.32 in the next 6 weeks
# Store Number 665 will sell R$252,702.02 in the next 6 weeks
# Store Number 666 will sell R$270,861.95 in the next 6 weeks
# Store Number 667 will sell R$344,282.83 in the next 6 weeks
# Store Number 669 will sell R$170,892.11 in the next 6 weeks
# Store Number 670 will sell R$295,777.90 in the next 6 weeks
# Store Number 671 will sell R$325,422.73 in the next 6 weeks
# Store Number 673 will sell R$230,712.89 in the next 6 weeks
# Store Number 674 will sell R$269,624.48 in the next 6 weeks
# Store Number 675 will sell R$171,570.90 in the next 6 weeks
# Store Number 676 will sell R$437,725.92 in the next 6 weeks
# Store Number 677 will sell R$234,795.24 in the next 6 weeks
# Store Number 678 will sell R$290,938.82 in the next 6 weeks
# Store Number 680 will sell R$254,532.13 in the next 6 weeks
# Store Number 681 will sell R$215,256.01 in the next 6 weeks
# Store Number 684 will sell R$269,992.45 in the next 6 weeks
# Store Number 685 will sell R$341,345.53 in the next 6 weeks
# Store Number 687 will sell R$355,763.78 in the next 6 weeks
# Store Number 689 will sell R$222,936.57 in the next 6 weeks
# Store Number 690 will sell R$324,993.21 in the next 6 weeks
# Store Number 691 will sell R$299,988.10 in the next 6 weeks
# Store Number 692 will sell R$187,299.52 in the next 6 weeks
# Store Number 693 will sell R$331,502.21 in the next 6 weeks
# Store Number 694 will sell R$437,320.85 in the next 6 weeks
# Store Number 695 will sell R$192,315.09 in the next 6 weeks
# Store Number 696 will sell R$368,441.28 in the next 6 weeks
# Store Number 697 will sell R$376,134.74 in the next 6 weeks
# Store Number 699 will sell R$400,049.42 in the next 6 weeks
# Store Number 700 will sell R$151,231.69 in the next 6 weeks
# Store Number 701 will sell R$229,871.64 in the next 6 weeks
# Store Number 702 will sell R$183,525.29 in the next 6 weeks
# Store Number 703 will sell R$105,566.53 in the next 6 weeks
# Store Number 705 will sell R$307,129.02 in the next 6 weeks
# Store Number 706 will sell R$226,664.73 in the next 6 weeks
# Store Number 707 will sell R$349,794.66 in the next 6 weeks
# Store Number 710 will sell R$206,531.92 in the next 6 weeks
# Store Number 711 will sell R$257,399.35 in the next 6 weeks
# Store Number 712 will sell R$242,698.16 in the next 6 weeks
# Store Number 713 will sell R$379,447.48 in the next 6 weeks
# Store Number 714 will sell R$180,521.00 in the next 6 weeks
# Store Number 716 will sell R$214,117.52 in the next 6 weeks
# Store Number 717 will sell R$412,343.33 in the next 6 weeks
# Store Number 718 will sell R$249,038.43 in the next 6 weeks
# Store Number 719 will sell R$233,102.27 in the next 6 weeks
# Store Number 720 will sell R$257,099.11 in the next 6 weeks
# Store Number 721 will sell R$330,122.84 in the next 6 weeks
# Store Number 722 will sell R$394,616.00 in the next 6 weeks
# Store Number 723 will sell R$246,450.68 in the next 6 weeks
# Store Number 724 will sell R$304,946.85 in the next 6 weeks
# Store Number 725 will sell R$245,425.21 in the next 6 weeks
# Store Number 727 will sell R$253,053.91 in the next 6 weeks
# Store Number 728 will sell R$205,978.30 in the next 6 weeks
# Store Number 729 will sell R$341,662.16 in the next 6 weeks
# Store Number 731 will sell R$356,936.29 in the next 6 weeks
# Store Number 732 will sell R$232,347.27 in the next 6 weeks
# Store Number 733 will sell R$360,537.99 in the next 6 weeks
# Store Number 734 will sell R$365,811.64 in the next 6 weeks
# Store Number 736 will sell R$236,081.20 in the next 6 weeks
# Store Number 737 will sell R$236,061.76 in the next 6 weeks
# Store Number 738 will sell R$303,265.86 in the next 6 weeks
# Store Number 739 will sell R$362,365.03 in the next 6 weeks
# Store Number 740 will sell R$263,549.93 in the next 6 weeks
# Store Number 741 will sell R$228,333.32 in the next 6 weeks
# Store Number 742 will sell R$327,534.66 in the next 6 weeks
# Store Number 744 will sell R$265,039.16 in the next 6 weeks
# Store Number 746 will sell R$257,920.57 in the next 6 weeks
# Store Number 748 will sell R$227,368.78 in the next 6 weeks
# Store Number 749 will sell R$244,742.93 in the next 6 weeks
# Store Number 750 will sell R$222,373.95 in the next 6 weeks
# Store Number 751 will sell R$245,912.02 in the next 6 weeks
# Store Number 752 will sell R$189,183.90 in the next 6 weeks
# Store Number 753 will sell R$350,055.54 in the next 6 weeks
# Store Number 756 will sell R$487,994.96 in the next 6 weeks
# Store Number 757 will sell R$319,312.79 in the next 6 weeks
# Store Number 758 will sell R$243,860.61 in the next 6 weeks
# Store Number 759 will sell R$246,243.99 in the next 6 weeks
# Store Number 762 will sell R$212,443.28 in the next 6 weeks
# Store Number 763 will sell R$171,985.06 in the next 6 weeks
# Store Number 764 will sell R$89,447.69 in the next 6 weeks
# Store Number 765 will sell R$359,404.80 in the next 6 weeks
# Store Number 766 will sell R$228,122.12 in the next 6 weeks
# Store Number 767 will sell R$137,420.63 in the next 6 weeks
# Store Number 768 will sell R$409,032.26 in the next 6 weeks
# Store Number 769 will sell R$295,252.92 in the next 6 weeks
# Store Number 770 will sell R$302,216.27 in the next 6 weeks
# Store Number 771 will sell R$282,606.18 in the next 6 weeks
# Store Number 772 will sell R$297,499.36 in the next 6 weeks
# Store Number 773 will sell R$290,485.44 in the next 6 weeks
# Store Number 774 will sell R$299,616.91 in the next 6 weeks
# Store Number 775 will sell R$333,532.69 in the next 6 weeks
# Store Number 776 will sell R$237,426.62 in the next 6 weeks
# Store Number 777 will sell R$149,574.68 in the next 6 weeks
# Store Number 778 will sell R$247,410.37 in the next 6 weeks
# Store Number 782 will sell R$223,594.63 in the next 6 weeks
# Store Number 784 will sell R$208,924.58 in the next 6 weeks
# Store Number 785 will sell R$169,752.49 in the next 6 weeks
# Store Number 789 will sell R$124,864.11 in the next 6 weeks
# Store Number 790 will sell R$209,785.57 in the next 6 weeks
# Store Number 791 will sell R$270,019.79 in the next 6 weeks
# Store Number 792 will sell R$288,585.55 in the next 6 weeks
# Store Number 793 will sell R$185,067.24 in the next 6 weeks
# Store Number 795 will sell R$200,451.53 in the next 6 weeks
# Store Number 796 will sell R$256,718.28 in the next 6 weeks
# Store Number 797 will sell R$154,790.70 in the next 6 weeks
# Store Number 799 will sell R$330,129.26 in the next 6 weeks
# Store Number 800 will sell R$233,280.12 in the next 6 weeks
# Store Number 801 will sell R$182,713.24 in the next 6 weeks
# Store Number 802 will sell R$306,459.71 in the next 6 weeks
# Store Number 803 will sell R$289,172.59 in the next 6 weeks
# Store Number 804 will sell R$192,022.53 in the next 6 weeks
# Store Number 805 will sell R$201,457.18 in the next 6 weeks
# Store Number 806 will sell R$346,994.87 in the next 6 weeks
# Store Number 807 will sell R$349,957.47 in the next 6 weeks
# Store Number 809 will sell R$225,955.02 in the next 6 weeks
# Store Number 810 will sell R$231,907.95 in the next 6 weeks
# Store Number 811 will sell R$243,443.59 in the next 6 weeks
# Store Number 813 will sell R$257,541.52 in the next 6 weeks
# Store Number 815 will sell R$367,776.02 in the next 6 weeks
# Store Number 816 will sell R$325,074.22 in the next 6 weeks
# Store Number 818 will sell R$246,597.22 in the next 6 weeks
# Store Number 819 will sell R$256,558.92 in the next 6 weeks
# Store Number 820 will sell R$341,562.08 in the next 6 weeks
# Store Number 822 will sell R$474,551.89 in the next 6 weeks
# Store Number 823 will sell R$229,731.68 in the next 6 weeks
# Store Number 824 will sell R$285,887.43 in the next 6 weeks
# Store Number 825 will sell R$248,336.47 in the next 6 weeks
# Store Number 826 will sell R$272,511.73 in the next 6 weeks
# Store Number 829 will sell R$253,785.12 in the next 6 weeks
# Store Number 831 will sell R$329,387.25 in the next 6 weeks
# Store Number 832 will sell R$229,645.29 in the next 6 weeks
# Store Number 833 will sell R$219,058.96 in the next 6 weeks
# Store Number 835 will sell R$248,290.36 in the next 6 weeks
# Store Number 837 will sell R$262,201.52 in the next 6 weeks
# Store Number 840 will sell R$256,647.18 in the next 6 weeks
# Store Number 842 will sell R$587,202.15 in the next 6 weeks
# Store Number 844 will sell R$217,452.48 in the next 6 weeks
# Store Number 845 will sell R$191,164.60 in the next 6 weeks
# Store Number 846 will sell R$377,640.56 in the next 6 weeks
# Store Number 847 will sell R$305,357.90 in the next 6 weeks
# Store Number 848 will sell R$357,368.98 in the next 6 weeks
# Store Number 849 will sell R$292,961.89 in the next 6 weeks
# Store Number 850 will sell R$183,305.59 in the next 6 weeks
# Store Number 851 will sell R$195,294.46 in the next 6 weeks
# Store Number 852 will sell R$202,875.92 in the next 6 weeks
# Store Number 853 will sell R$298,058.06 in the next 6 weeks
# Store Number 855 will sell R$283,304.20 in the next 6 weeks
# Store Number 856 will sell R$229,827.89 in the next 6 weeks
# Store Number 857 will sell R$248,891.39 in the next 6 weeks
# Store Number 858 will sell R$167,259.91 in the next 6 weeks
# Store Number 859 will sell R$402,093.85 in the next 6 weeks
# Store Number 860 will sell R$206,270.53 in the next 6 weeks
# Store Number 861 will sell R$144,262.86 in the next 6 weeks
# Store Number 862 will sell R$374,339.53 in the next 6 weeks
# Store Number 863 will sell R$231,135.33 in the next 6 weeks
# Store Number 864 will sell R$217,304.66 in the next 6 weeks
# Store Number 865 will sell R$284,313.32 in the next 6 weeks
# Store Number 866 will sell R$286,028.62 in the next 6 weeks
# Store Number 867 will sell R$319,710.30 in the next 6 weeks
# Store Number 868 will sell R$343,153.37 in the next 6 weeks
# Store Number 871 will sell R$312,528.44 in the next 6 weeks
# Store Number 872 will sell R$276,343.23 in the next 6 weeks
# Store Number 874 will sell R$236,292.51 in the next 6 weeks
# Store Number 875 will sell R$195,683.89 in the next 6 weeks
# Store Number 877 will sell R$241,796.07 in the next 6 weeks
# Store Number 879 will sell R$134,350.07 in the next 6 weeks
# Store Number 880 will sell R$364,736.09 in the next 6 weeks
# Store Number 881 will sell R$235,067.60 in the next 6 weeks
# Store Number 882 will sell R$220,204.00 in the next 6 weeks
# Store Number 883 will sell R$165,812.92 in the next 6 weeks
# Store Number 884 will sell R$250,357.28 in the next 6 weeks
# Store Number 885 will sell R$221,300.68 in the next 6 weeks
# Store Number 886 will sell R$249,176.47 in the next 6 weeks
# Store Number 887 will sell R$315,450.07 in the next 6 weeks
# Store Number 888 will sell R$308,482.80 in the next 6 weeks
# Store Number 890 will sell R$260,872.90 in the next 6 weeks
# Store Number 891 will sell R$380,681.63 in the next 6 weeks
# Store Number 893 will sell R$302,063.71 in the next 6 weeks
# Store Number 894 will sell R$206,564.82 in the next 6 weeks
# Store Number 895 will sell R$442,748.36 in the next 6 weeks
# Store Number 896 will sell R$192,451.84 in the next 6 weeks
# Store Number 897 will sell R$134,522.82 in the next 6 weeks
# Store Number 900 will sell R$207,328.17 in the next 6 weeks
# Store Number 901 will sell R$230,258.61 in the next 6 weeks
# Store Number 902 will sell R$300,104.69 in the next 6 weeks
# Store Number 903 will sell R$307,800.39 in the next 6 weeks
# Store Number 904 will sell R$272,346.80 in the next 6 weeks
# Store Number 905 will sell R$221,416.09 in the next 6 weeks
# Store Number 906 will sell R$313,609.38 in the next 6 weeks
# Store Number 907 will sell R$292,605.42 in the next 6 weeks
# Store Number 908 will sell R$187,417.08 in the next 6 weeks
# Store Number 909 will sell R$375,410.69 in the next 6 weeks
# Store Number 911 will sell R$331,145.41 in the next 6 weeks
# Store Number 912 will sell R$261,044.91 in the next 6 weeks
# Store Number 913 will sell R$345,154.83 in the next 6 weeks
# Store Number 914 will sell R$334,010.57 in the next 6 weeks
# Store Number 915 will sell R$263,324.58 in the next 6 weeks
# Store Number 916 will sell R$161,596.43 in the next 6 weeks
# Store Number 917 will sell R$223,500.82 in the next 6 weeks
# Store Number 919 will sell R$201,843.57 in the next 6 weeks
# Store Number 920 will sell R$187,934.95 in the next 6 weeks
# Store Number 922 will sell R$240,882.52 in the next 6 weeks
# Store Number 924 will sell R$195,674.44 in the next 6 weeks
# Store Number 925 will sell R$301,934.96 in the next 6 weeks
# Store Number 926 will sell R$282,518.83 in the next 6 weeks
# Store Number 927 will sell R$360,945.44 in the next 6 weeks
# Store Number 928 will sell R$286,418.42 in the next 6 weeks
# Store Number 929 will sell R$227,278.53 in the next 6 weeks
# Store Number 930 will sell R$298,265.84 in the next 6 weeks
# Store Number 931 will sell R$202,830.94 in the next 6 weeks
# Store Number 932 will sell R$320,688.12 in the next 6 weeks
# Store Number 934 will sell R$255,026.76 in the next 6 weeks
# Store Number 935 will sell R$321,289.01 in the next 6 weeks
# Store Number 936 will sell R$280,914.98 in the next 6 weeks
# Store Number 937 will sell R$335,351.05 in the next 6 weeks
# Store Number 938 will sell R$258,985.76 in the next 6 weeks
# Store Number 939 will sell R$324,572.07 in the next 6 weeks
# Store Number 941 will sell R$180,078.38 in the next 6 weeks
# Store Number 942 will sell R$289,556.92 in the next 6 weeks
# Store Number 943 will sell R$232,982.02 in the next 6 weeks
# Store Number 944 will sell R$273,505.76 in the next 6 weeks
# Store Number 945 will sell R$205,493.35 in the next 6 weeks
# Store Number 946 will sell R$152,474.95 in the next 6 weeks
# Store Number 947 will sell R$310,056.38 in the next 6 weeks
# Store Number 948 will sell R$458,491.19 in the next 6 weeks
# Store Number 950 will sell R$207,468.69 in the next 6 weeks
# Store Number 951 will sell R$283,643.95 in the next 6 weeks
# Store Number 952 will sell R$237,062.79 in the next 6 weeks
# Store Number 954 will sell R$280,433.01 in the next 6 weeks
# Store Number 955 will sell R$158,340.57 in the next 6 weeks
# Store Number 956 will sell R$146,171.69 in the next 6 weeks
# Store Number 960 will sell R$275,518.07 in the next 6 weeks
# Store Number 961 will sell R$263,787.65 in the next 6 weeks
# Store Number 962 will sell R$198,153.40 in the next 6 weeks
# Store Number 964 will sell R$319,057.38 in the next 6 weeks
# Store Number 965 will sell R$268,868.28 in the next 6 weeks
# Store Number 966 will sell R$237,097.63 in the next 6 weeks
# Store Number 967 will sell R$260,664.56 in the next 6 weeks
# Store Number 969 will sell R$132,710.93 in the next 6 weeks
# Store Number 970 will sell R$198,853.99 in the next 6 weeks
# Store Number 973 will sell R$328,485.88 in the next 6 weeks
# Store Number 974 will sell R$319,446.57 in the next 6 weeks
# Store Number 975 will sell R$324,353.44 in the next 6 weeks
# Store Number 976 will sell R$345,758.79 in the next 6 weeks
# Store Number 977 will sell R$206,473.45 in the next 6 weeks
# Store Number 980 will sell R$281,164.82 in the next 6 weeks
# Store Number 983 will sell R$294,706.83 in the next 6 weeks
# Store Number 984 will sell R$296,020.45 in the next 6 weeks
# Store Number 985 will sell R$321,891.63 in the next 6 weeks
# Store Number 986 will sell R$193,213.27 in the next 6 weeks
# Store Number 988 will sell R$191,473.92 in the next 6 weeks
# Store Number 989 will sell R$187,313.46 in the next 6 weeks
# Store Number 991 will sell R$267,120.07 in the next 6 weeks
# Store Number 992 will sell R$215,721.49 in the next 6 weeks
# Store Number 994 will sell R$155,275.52 in the next 6 weeks
# Store Number 997 will sell R$197,300.90 in the next 6 weeks
# Store Number 998 will sell R$168,013.46 in the next 6 weeks
# Store Number 1000 will sell R$219,224.85 in the next 6 weeks
# Store Number 1003 will sell R$224,808.90 in the next 6 weeks
# Store Number 1004 will sell R$173,915.37 in the next 6 weeks
# Store Number 1005 will sell R$322,270.32 in the next 6 weeks
# Store Number 1007 will sell R$280,930.18 in the next 6 weeks
# Store Number 1008 will sell R$209,531.28 in the next 6 weeks
# Store Number 1009 will sell R$185,279.00 in the next 6 weeks
# Store Number 1010 will sell R$341,278.17 in the next 6 weeks
# Store Number 1011 will sell R$375,346.16 in the next 6 weeks
# Store Number 1012 will sell R$236,897.17 in the next 6 weeks
# Store Number 1013 will sell R$173,324.58 in the next 6 weeks
# Store Number 1014 will sell R$284,097.06 in the next 6 weeks
# Store Number 1015 will sell R$256,264.29 in the next 6 weeks
# Store Number 1016 will sell R$300,008.76 in the next 6 weeks
# Store Number 1019 will sell R$322,062.80 in the next 6 weeks
# Store Number 1020 will sell R$233,144.24 in the next 6 weeks
# Store Number 1022 will sell R$477,987.87 in the next 6 weeks
# Store Number 1024 will sell R$205,906.62 in the next 6 weeks
# Store Number 1025 will sell R$329,995.51 in the next 6 weeks
# Store Number 1026 will sell R$364,518.19 in the next 6 weeks
# Store Number 1027 will sell R$343,126.05 in the next 6 weeks
# Store Number 1028 will sell R$183,562.02 in the next 6 weeks
# Store Number 1031 will sell R$258,133.42 in the next 6 weeks
# Store Number 1036 will sell R$228,556.79 in the next 6 weeks
# Store Number 1037 will sell R$223,081.18 in the next 6 weeks
# Store Number 1038 will sell R$253,678.42 in the next 6 weeks
# Store Number 1039 will sell R$218,841.49 in the next 6 weeks
# Store Number 1040 will sell R$363,429.87 in the next 6 weeks
# Store Number 1041 will sell R$259,668.25 in the next 6 weeks
# Store Number 1042 will sell R$224,416.05 in the next 6 weeks
# Store Number 1044 will sell R$274,339.06 in the next 6 weeks
# Store Number 1045 will sell R$292,228.20 in the next 6 weeks
# Store Number 1047 will sell R$228,452.22 in the next 6 weeks
# Store Number 1048 will sell R$261,566.75 in the next 6 weeks
# Store Number 1049 will sell R$226,806.99 in the next 6 weeks
# Store Number 1050 will sell R$288,284.26 in the next 6 weeks
# Store Number 1051 will sell R$234,072.43 in the next 6 weeks
# Store Number 1052 will sell R$320,668.69 in the next 6 weeks
# Store Number 1053 will sell R$377,275.22 in the next 6 weeks
# Store Number 1054 will sell R$194,814.91 in the next 6 weeks
# Store Number 1056 will sell R$165,394.51 in the next 6 weeks
# Store Number 1057 will sell R$243,426.38 in the next 6 weeks
# Store Number 1058 will sell R$251,811.90 in the next 6 weeks
# Store Number 1059 will sell R$308,045.56 in the next 6 weeks
# Store Number 1060 will sell R$355,250.15 in the next 6 weeks
# Store Number 1061 will sell R$338,633.41 in the next 6 weeks
# Store Number 1062 will sell R$161,100.42 in the next 6 weeks
# Store Number 1063 will sell R$234,857.63 in the next 6 weeks
# Store Number 1064 will sell R$385,895.49 in the next 6 weeks
# Store Number 1065 will sell R$202,704.75 in the next 6 weeks
# Store Number 1066 will sell R$440,990.14 in the next 6 weeks
# Store Number 1067 will sell R$227,291.36 in the next 6 weeks
# Store Number 1068 will sell R$182,167.27 in the next 6 weeks
# Store Number 1070 will sell R$284,495.55 in the next 6 weeks
# Store Number 1071 will sell R$243,415.15 in the next 6 weeks
# Store Number 1072 will sell R$269,424.61 in the next 6 weeks
# Store Number 1073 will sell R$302,921.52 in the next 6 weeks
# Store Number 1076 will sell R$146,319.88 in the next 6 weeks
# Store Number 1077 will sell R$183,971.83 in the next 6 weeks
# Store Number 1078 will sell R$286,031.58 in the next 6 weeks
# Store Number 1079 will sell R$306,823.71 in the next 6 weeks
# Store Number 1080 will sell R$366,084.47 in the next 6 weeks
# Store Number 1083 will sell R$219,572.82 in the next 6 weeks
# Store Number 1084 will sell R$212,717.70 in the next 6 weeks
# Store Number 1086 will sell R$163,467.16 in the next 6 weeks
# Store Number 1087 will sell R$228,280.52 in the next 6 weeks
# Store Number 1088 will sell R$188,087.28 in the next 6 weeks
# Store Number 1089 will sell R$378,065.39 in the next 6 weeks
# Store Number 1091 will sell R$392,629.08 in the next 6 weeks
# Store Number 1092 will sell R$340,612.94 in the next 6 weeks
# Store Number 1094 will sell R$209,147.56 in the next 6 weeks
# Store Number 1096 will sell R$231,202.33 in the next 6 weeks
# Store Number 1097 will sell R$387,124.89 in the next 6 weeks
# Store Number 1099 will sell R$212,488.34 in the next 6 weeks
# Store Number 1100 will sell R$306,298.40 in the next 6 weeks
# Store Number 1101 will sell R$399,397.84 in the next 6 weeks
# Store Number 1102 will sell R$243,604.10 in the next 6 weeks
# Store Number 1103 will sell R$174,189.64 in the next 6 weeks
# Store Number 1104 will sell R$196,864.93 in the next 6 weeks
# Store Number 1105 will sell R$169,393.49 in the next 6 weeks
# Store Number 1106 will sell R$197,634.34 in the next 6 weeks
# Store Number 1107 will sell R$250,226.51 in the next 6 weeks
# Store Number 1109 will sell R$191,705.11 in the next 6 weeks
# Store Number 1111 will sell R$197,144.00 in the next 6 weeks
# Store Number 1112 will sell R$356,114.37 in the next 6 weeks
# Store Number 1113 will sell R$293,221.64 in the next 6 weeks
# Store Number 1114 will sell R$771,163.30 in the next 6 weeks
# Store Number 1115 will sell R$279,950.22 in the next 6 weeks
